# %%
org_name = 'mko'
org_full_name = 'Methylomonas_koyamae'

# %%
org_name = 'mbry'
org_full_name = 'Methylocystis_bryophila'

# %%
org_name = 'mca'
org_full_name = 'Methylococcus_capsulatus'

# %%
import cobra
old_model = cobra.io.read_sbml_model(org_name+'\\08_'+org_name+'_complete_model_V1.xml')

# %%
a = old_model.optimize()
a.fluxes.to_csv(org_name+'\\08_'+org_name+'_origin_fluxes.csv')
old_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass_reaction = 0.42391558713783645</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.003397</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ch4_e</td>
#       <td>EX_ch4_e</td>
#       <td>30</td>
#       <td>1</td>
#       <td>85.08%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>0.0003397</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>0.003397</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>0.002079</td>
# ...

# %%
old_model.objective = 'EX_ac_e'

# %%
old_model.optimize().fluxes.to_csv(org_name+'\\09_'+org_name+'_EX_ac_fluxes.csv')

# %%
old_model.remove_reactions([old_model.reactions.get_by_id('SK_amp_c')])

# %%
old_model.reactions.get_by_id('EX_o2_e').bounds = (-1000,0)

# %%
old_model.reactions.get_by_id('EX_co2_e').bounds = (0,20)

# %%
old_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass_reaction = 0.3715991624319416</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.002978</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ch4_e</td>
#       <td>EX_ch4_e</td>
#       <td>19.93</td>
#       <td>1</td>
#       <td>79.17%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>0.0002978</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>0.002978</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>0.001822</td>
# ...

# %%
optimize_dict = {}
for rxn in old_model.reactions:
    old_model.objective = rxn
    a=old_model.optimize()
    optimize_dict[rxn.id] = a.objective_value

print(len(optimize_dict))
zero_rxn = []
for key, value in optimize_dict.items():
    if value == 0:
        zero_rxn.append(key)
print(len(zero_rxn))
# Out:
# 761
# 540

# %%
for key, value in optimize_dict.items():
    print(key, value)
# Out:
# PMMO 30.0
# MeDH 30.0
# FAE 30.0
# MTD 29.999999999999996
# MCH 29.999999999999996
# FTR 0.0
# FWDf 10.0
# FWD 30.0
# FDH 29.999999999999993
# H6PS 1000.0
# H6PI 1000.0
# MDH 1000.0
# MACOAli 20.0
# MLCOAly 20.0
# ACS 1000.0
# SPT_syn 1000.0
# GLYCK2 0.0
# PGCD 1000.0
# PSERT 1000.0
# PSP_L 1000.0
# GHMT1 20.0
# BFBP 1000.0
# G6PI3 1000.0
# G6PI_1 1000.0
# G6PBDH 1000.0
# PGL 1000.0
# GND 30.000000000000227
# EDD 1000.0
# EDA 1000.0
# PFKppi 1000.0
# FBA 10.0
# TKT1 0.0
# TKT2 10.0
# TALA 10.0
# RPI 10.0
# RPE 0.0
# AH6PI 1000.0
# RU5PS 30.0
# TPI 10.0
# GAPD 10.000000000000378
# PGK 10.000000000000378
# PGM 10.0
# ENO 10.0
# PYK 1000.0
# POR_syn 10.0
# GLUKA 0.0
# GLUK_syn 0.0
# PGCM 0.0
# PPDK 1000.0
# PPS 1000.0
# ALCD2x 1000.0
# ALCD2y 1000.0
# PDHa1 10.0
# PDHa2 10.0
# PDHbr 10.0
# LDP 20.0
# PC 1000.0
# CS 20.0
# ACONTa 20.0
# ACONTb 20.0
# ICDHx 1000.0
# r0422 1000.0
# r0082 1000.0
# AKGDa1 20.0
# AKGDa2 20.0
# AKGDb 20.0
# SUCOAS 4.999999999999995
# SUCDH 19.999999999999993
# ...

# %%
# Out:
# 761
# 536

# %%
import myModules.buildmodel as BM

# %%
carveme_model = cobra.io.read_sbml_model(org_name+'\\automodel\\'+org_name+'_carveme_model.xml')

# %%
for mete in old_model.reactions.get_by_id("Biomass_reaction").metabolites:
# Out:
# {<Metabolite h2o_c at 0x259552966d0>: -59.81,
#  <Metabolite ctp_c at 0x259582765b0>: -0.0604,
#  <Metabolite nadph_c at 0x25955296760>: -0.00080136,
#  <Metabolite nadp_c at 0x25955296700>: -0.00080136,
#  <Metabolite hdca_c at 0x259583127f0>: -0.0075,
#  <Metabolite ser__L_c at 0x25955296c40>: -0.27727,
#  <Metabolite amet_c at 0x25958276a60>: -0.0001763,
#  <Metabolite nadh_c at 0x25955296940>: -0.0016027,
#  <Metabolite nad_c at 0x25955296910>: -0.0016027,
#  <Metabolite utp_c at 0x25958276580>: -0.0604,
#  <Metabolite atp_c at 0x25955296a60>: -59.8782,
#  <Metabolite gly_c at 0x25955296c70>: -0.53405,
#  <Metabolite glu__L_c at 0x25955296d90>: -0.47739,
#  <Metabolite coa_c at 0x25955296bb0>: -0.0001763,
#  <Metabolite pyr_c at 0x25955296430>: -0.01202,
#  <Metabolite accoa_c at 0x25955296b20>: -8.0136e-05,
#  <Metabolite 6pgc_c at 0x25955296ee0>: -0.0001202,
#  <Metabolite ru5p__D_c at 0x25955296970>: -0.00080136,
#  <Metabolite ala__L_c at 0x259582df2e0>: -0.53767,
# ...

# %%
carveme_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth = 44.97937785484112</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3cmp_e</td>
#       <td>EX_3cmp_e</td>
#       <td>44.35</td>
#       <td>9</td>
#       <td>4.87%</td>
#     </tr>
#     <tr>
#       <td>LalaDgluMdapDala_e</td>
#       <td>EX_LalaDgluMdapDala_e</td>
#       <td>4.498</td>
#       <td>18</td>
#       <td>0.99%</td>
#     </tr>
#     <tr>
#       <td>arg__L_e</td>
#       <td>EX_arg__L_e</td>
#       <td>13.3</td>
#       <td>6</td>
#       <td>0.97%</td>
#     </tr>
#     <tr>
#       <td>bz_e</td>
#       <td>EX_bz_e</td>
#       <td>0.004498</td>
#       <td>7</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.2341</td>
# ...

# %%
imc_model = cobra.io.read_sbml_model('other_model\\iMcBath.xml')
imc_model
# Out:
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# ...

# %%
for me,sto in imc_model.reactions.BIOMASS_Mcapsulatus.metabolites.items():
    print(me.id,'\t',sto,'\t',me.name)
# Out:
# 2ddg6p_c 	 -3e-06 	 2-dehydro-3-deoxy-6-phosphonato-D-gluconate(3-)
# 2pg_c 	 -0.006 	 2-phospho-D-glycerate
# 6pgc_c 	 -0.00015 	 6-phosphonatooxy-D-gluconate
# accoa_c 	 -0.0001 	 acetyl-CoA(4-)
# adocbl_c 	 -6e-08 	 adenosylcobalamin
# ala__L_c 	 -0.576 	 L-alanine zwitterion
# amet_c 	 -0.00022 	 S-adenosyl-L-methionine
# arg__L_c 	 -0.254 	 L-argininium(1+)
# asn__L_c 	 -0.119 	 L-asparagine zwitterion
# asp__L_c 	 -0.468 	 L-aspartate(1-)
# atp_c 	 -23.11185589 	 ATP
# ca2_c 	 -0.06986377 	 Ca(2+)
# cit_c 	 -0.001 	 citrate
# cl_c 	 -0.21438646 	 Cl(-)
# clpn_MC_c 	 -3.15904e-06 	 Cardiolipin
# coa_c 	 -0.00022 	 CoA
# cobalt2_c 	 -5.769e-05 	 Co(2+)
# colipa_e 	 -0.002 	 colipa_e
# cpoa2h_c 	 -0.00186552 	 Cyclopropaneoctanoic acid 2-hexyl
# ctp_c 	 -0.04425885 	 CTP(3-)
# cu2_c 	 -0.00151072 	 Cu2+
# cys__L_c 	 -0.038 	 L-cysteine zwitterion
# datp_c 	 -0.00866366 	 dATP
# dctp_c 	 -0.01571821 	 dCTP(3-)
# dgtp_c 	 -0.01446787 	 dGTP(3-)
# ...

# %%
solution = cobra.flux_analysis.gapfill(old_model, imc_model, demand_reactions=False)
# Out:
# ---------------------------------------------------------------------------
# Infeasible                                Traceback (most recent call last)
# c:\Users\lix\Documents\GitHub\BuildGEM\4_Gipfilling.ipynb 单元格 15 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lix/Documents/GitHub/BuildGEM/4_Gipfilling.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> solution = cobra.flux_analysis.gapfill(old_model, imc_model, demand_reactions=False)
#
# File c:\Users\lix\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\flux_analysis\gapfilling.py:407, in gapfill(model, universal, lower_bound, penalties, demand_reactions, exchange_reactions, iterations)
#     348 """Perform gap filling on a model.
#     349
#     350 Parameters
#    (...)
#     397
#     398 """
#     399 gapfiller = GapFiller(
#     400     model,
#     401     universal=universal,
#    (...)
#     405     exchange_reactions=exchange_reactions,
#     406 )
# --> 407 return gapfiller.fill(iterations=iterations)
#
# ...

# %%
for reaction in solution[0]:
    print(reaction.id)

# %%
bigg_model = cobra.io.load_json_model('.\\BIGG\\universal_model_modified.json')

# %%
l2 = len(bigg_model.reactions)-10

# %%
def check_not_c(rxn):
    for met in rxn.metabolites:
        if not met.id.endswith('_c'):
            return True
    return False

# %%
end2 =3
end1 =2
print("time2: "+str((end2-end1))+"s")
# Out:
# time2: 1s

# %%
with open('removel_bigg_model_reactions.txt', 'w') as f:
    for rxn in bigg_model.reactions:
        if check_not_c(rxn):
            f.write(rxn.id+'\n')
            bigg_model.remove_reactions([rxn])
f.close()

# %%
bigg_model
# Out:
# <Model bigg_universal at 0x276646de370>
