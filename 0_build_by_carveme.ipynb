# %%
# https://carveme.readthedocs.io/en/latest/installation.html
pip install carveme

# %%
pip install -c bioconda diamond
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'bioconda'
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
org_name = 'mko'
org_full_name = 'Methylomonas_koyamae'

# %%
org_name = 'mbry'
org_full_name = 'Methylocystis_bryophila'

# %%
import os
for root, dirs, files in os.walk(org_full_name+'_genome'):
    if 'protein.faa' in files:
        genome_path = root+'\\protein.faa'

# %%
print('carve',genome_path,'--gapfill M9 --mediadb media_db.tsv','--output',org_name+'_model\\'+org_name+'_carveme_model.xml')
# Out:
# carve Methylomonas_koyamae_genome\ncbi_dataset\data\GCF_019669905.1\protein.faa --gapfill M9 --mediadb media_db.tsv --output mko_model\mko_carveme_model.xml

# %%
# carve Methylocystis_bryophila_genome\ncbi_dataset\data\GCA_027925445.1\protein.faa -u gramneg --gapfill M1409 --mediadb media_db.tsv -o mbry_carveme_model.xml

# %%
import cobra
model = cobra.io.read_sbml_model('mbry_carveme_model.xml')

# %%
carve Methylocystis_bryophila_genome\ncbi_dataset\data\GCA_027925445.1\protein.faa -u gramneg --gapfill M9 --mediadb media_db.tsv -o mbry_carveme_model.xml

# %%
model
# Out:
# <Model mbry_carveme_model at 0x2b1915ad550>

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth = 43.132407225340685</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2obut_e</td>
#       <td>EX_2obut_e</td>
#       <td>157</td>
#       <td>4</td>
#       <td>7.79%</td>
#     </tr>
#     <tr>
#       <td>4abut_e</td>
#       <td>EX_4abut_e</td>
#       <td>0.05642</td>
#       <td>4</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>arg__L_e</td>
#       <td>EX_arg__L_e</td>
#       <td>12.76</td>
#       <td>6</td>
#       <td>0.95%</td>
#     </tr>
#     <tr>
#       <td>bz_e</td>
#       <td>EX_bz_e</td>
#       <td>0.004313</td>
#       <td>7</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.2245</td>
#       <td>0</td>
# ...
