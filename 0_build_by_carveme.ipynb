# %%
# https://carveme.readthedocs.io/en/latest/installation.html
pip install carveme

# %%
pip install -c bioconda diamond
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'bioconda'
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
org_name = 'mko'
org_full_name = 'Methylomonas_koyamae'

# %%
org_name = 'mbry'
org_full_name = 'Methylocystis_bryophila'

# %%
import os
for root, dirs, files in os.walk(org_full_name+'_genome'):
    if 'protein.faa' in files:
        genome_path = root+'\\protein.faa'

# %%
print(genome_path)
# Out:
# Methylocystis_bryophila_genome\ncbi_dataset\data\GCA_027925445.1\protein.faa

# %%
# carve Methylocystis_bryophila_genome\ncbi_dataset\data\GCA_027925445.1\protein.faa --output model.xml

# %%
import cobra
model = cobra.io.read_sbml_model('model.xml')

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth = 49.97079665001439</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2obut_e</td>
#       <td>EX_2obut_e</td>
#       <td>495.2</td>
#       <td>4</td>
#       <td>26.04%</td>
#     </tr>
#     <tr>
#       <td>4abut_e</td>
#       <td>EX_4abut_e</td>
#       <td>0.004997</td>
#       <td>4</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>arg__L_e</td>
#       <td>EX_arg__L_e</td>
#       <td>14.78</td>
#       <td>6</td>
#       <td>1.17%</td>
#     </tr>
#     <tr>
#       <td>asn__L_e</td>
#       <td>EX_asn__L_e</td>
#       <td>12.05</td>
#       <td>4</td>
#       <td>0.63%</td>
#     </tr>
#     <tr>
#       <td>bz_e</td>
#       <td>EX_bz_e</td>
#       <td>0.004997</td>
#       <td>7</td>
# ...
