# %%
org_name = 'mko'
org_full_name = 'Methylomonas_koyamae'

# %%
org_name = 'mbry'
org_full_name = 'Methylocystis_bryophila'

# %%
import cobra
model2 = cobra.io.read_sbml_model(org_name+'_model\\'+org_name+'_add_from_modelseed_4.xml')
#drift_model = cobra.io.read_sbml_model(org_name+'_model\\ModelSeed_model_'+org_full_name+'.xml')
model2
# Out:
# <Model Methylocystis_bryophila at 0x1d016ad7b20>

# %%
import cobra
model = cobra.io.read_sbml_model(org_name+'_model\\'+org_name+'_add_from_modelseed_4.xml_model.xml')
#drift_model = cobra.io.read_sbml_model(org_name+'_model\\ModelSeed_model_'+org_full_name+'.xml')
model
# Out:
# <Model Methylocystis_bryophila at 0x1d02157ea30>

# %%
rxnlist = [rxn.id for rxn in model.reactions]
for rxn in model2.reactions:
    if not rxn.id in rxnlist:
        print(rxn.id)
# Out:
# rxn13783_c0
# rxn13784_c0
# rxn13782_c0

# %%
mparmodel = cobra.io.read_sbml_model('other_model\\Methylocystis_parvus.xml')

# %%
imcmodel= cobra.io.read_sbml_model('iMcBath.xml')
# Out:
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/inchi/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/bigg.reaction/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/metanetx.reaction/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/metanetx.reaction/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# http://identifiers.org/metanetx.reaction/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id

# %%
for rxn in imcmodel.reactions:
    rxn.annotation={}
for met in imcmodel.metabolites:
    met.annotation={}
cobra.io.write_sbml_model(imcmodel, 'iMcBath2.xml')

# %%
bioreaction = model.reactions.get_by_id('bio1_biomass')
for metabolite, stoich in bioreaction.metabolites.items():
    print(metabolite.id, stoich)
    model.metabolites.get_by_id(metabolite.id)
# Out:
# cpd15352_c0 -0.00280615915959131
# cpd00205_c0 -0.00280615915959131
# cpd15500_c0 -0.00280615915959131
# cpd15665_c0 -0.0250105977108944
# cpd00254_c0 -0.00280615915959131
# cpd17043_c0 -1.0
# cpd15793_c0 -0.0311453449430676
# cpd00034_c0 -0.00280615915959131
# cpd17042_c0 -1.0
# cpd17041_c0 -1.0
# cpd15533_c0 -0.0311453449430676
# cpd15540_c0 -0.0311453449430676
# cpd00058_c0 -0.00280615915959131
# cpd00264_c0 -0.00280615915959131
# cpd15432_c0 -0.0250105977108944
# cpd00063_c0 -0.00280615915959131
# cpd15560_c0 -0.00280615915959131
# cpd00030_c0 -0.00280615915959131
# cpd00039_c0 -0.285438020490179
# cpd00050_c0 -0.00280615915959131
# cpd00054_c0 -0.179456352975885
# cpd00002_c0 -40.1101757365074
# cpd00104_c0 -0.00280615915959131
# cpd00035_c0 -0.427934380173264
# cpd00042_c0 -0.00280615915959131
# cpd10516_c0 -0.00280615915959131
# cpd00345_c0 -0.00280615915959131
# cpd00065_c0 -0.0472019191450218
# cpd00048_c0 -0.00280615915959131
# cpd00161_c0 -0.211072732780569
# cpd02229_c0 -0.0250105977108944
# cpd00062_c0 -0.0908319049068452
# cpd00021_c0 -0.00280615915959131
# cpd00220_c0 -0.00280615915959131
# cpd00017_c0 -0.00280615915959131
# cpd00129_c0 -0.184354665339991
# cpd00038_c0 -0.135406821203723
# cpd00107_c0 -0.375388847540127
# cpd00201_c0 -0.00280615915959131
# cpd00010_c0 -0.00280615915959131
# cpd00084_c0 -0.0761464922056484
# cpd11493_c0 -0.00280615915959131
# cpd00356_c0 -0.0202473667675315
# cpd00156_c0 -0.352233189091625
# cpd00118_c0 -0.00280615915959131
# cpd00037_c0 -0.00280615915959131
# cpd00132_c0 -0.200830806928348
# cpd00166_c0 -0.00280615915959131
# cpd00053_c0 -0.219088153012743
# cpd00066_c0 -0.154519490031345
# cpd00023_c0 -0.219088153012743
# cpd00051_c0 -0.246696822701341
# cpd00069_c0 -0.120676604606612
# cpd00001_c0 -35.5403092430435
# cpd00006_c0 -0.00280615915959131
# cpd00241_c0 -0.0202473667675315
# cpd00033_c0 -0.509869786991038
# cpd00028_c0 -0.00280615915959131
# cpd00016_c0 -0.00280615915959131
# cpd00060_c0 -0.127801422590767
# cpd00087_c0 -0.00280615915959131
# cpd00357_c0 -0.0117896059659044
# cpd00041_c0 -0.200830806928348
# cpd00003_c0 -0.00280615915959131
# cpd00119_c0 -0.0792636000737159
# cpd00557_c0 -0.00280615915959131
# cpd00322_c0 -0.241798510337235
# cpd00056_c0 -0.00280615915959131
# cpd00099_c0 -0.00280615915959131
# cpd00115_c0 -0.0117896059659044
# cpd00052_c0 -0.0841036156544863
# cpd00015_c0 -0.00280615915959131
# cpd00149_c0 -0.00280615915959131
# cpd11416_c0 1.0
# cpd15666_c0 0.0250105977108944
# cpd00067_c0 40.0
# cpd00008_c0 40.0
# cpd00009_c0 39.9971938408404
# cpd12370_c0 0.00280615915959131
# cpd01997_c0 0.00280615915959131
# cpd00012_c0 0.484592023739303
# cpd03422_c0 0.00280615915959131

# %%
solutionx = model.optimize()
solutionx.objective_value
# Out:
# 0.0

# %%
#bioreaction = model.reactions.get_by_id('bio1_biomass')
for metabolite in model.metabolites:
    model3= model.copy()
    try:
        model3.add_boundary(model3.metabolites.get_by_id(metabolite.id), type="demand")
    except:
        pass
    solution = model3.optimize()
    print(metabolite.id, solution.objective_value)
# Out:
# cpd02083_c0 0.0
# cpd00062_c0 0.0
# cpd12801_c0 0.0
# cpd18074_c0 0.0
# cpd12847_c0 0.0
# cpd00209_e0 0.0
# cpd00268_c0 0.0
# cpd00027_c0 0.0
# cpd08260_c0 0.0
# cpd15793_c0 0.0
# cpd00107_c0 0.0
# cpd00210_e0 0.0
# cpd02724_c0 0.0
# cpd09792_c0 0.0
# cpd11591_c0 0.0
# cpd00084_e0 0.0
# cpd00348_c0 0.0
# cpd00623_c0 0.0
# cpd00210_c0 0.0
# cpd00531_e0 0.0
# cpd00015_c0 0.0
# cpd00096_c0 0.0
# cpd00932_c0 0.0
# cpd00428_c0 0.0
# cpd00703_c0 0.0
# cpd02197_c0 0.0
# cpd03121_c0 0.0
# cpd11728_c0 0.0
# cpd14547_c0 0.0
# cpd11476_c0 0.0
# cpd11751_c0 0.0
# cpd19044_c0 0.0
# cpd00050_c0 0.0
# cpd00978_c0 0.0
# cpd00142_c0 0.0
# cpd01686_c0 0.0
# cpd00805_c0 0.0
# cpd15175_c0 0.0
# cpd02255_c0 0.0
# cpd15540_c0 0.0
# cpd12514_c0 0.0
# cpd00074_c0 0.0
# cpd00393_e0 0.0
# cpd00635_c0 0.0
# cpd12344_c0 0.0
# cpd00485_c0 0.0
# cpd00760_c0 0.0
# cpd00254_c0 0.0
# cpd00497_c0 0.0
# cpd03918_c0 0.0
# cpd11906_c0 0.0
# cpd00254_e0 0.0
# cpd04099_c0 0.0
# cpd00149_e0 0.0
# cpd00011_e0 0.0
# cpd02605_c0 0.0
# cpd00733_c0 0.0
# cpd03313_c0 0.0
# cpd08240_c0 0.0
# cpd00976_c0 0.0
# cpd14961_c0 0.0
# cpd00288_c0 0.0
# cpd01078_c0 0.0
# cpd04103_c0 0.0
# cpd00475_c0 0.0
# cpd02893_c0 0.0
# cpd09843_c0 0.0
# cpd08357_c0 0.0

# %%
model3.reactions.get_by_id('bio1_biomass')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 model3.reactions.get_by_id('bio1_biomass').stoichiometrys
#
# AttributeError: 'Reaction' object has no attribute 'stoichiometrys'

# %%
model3.reactions.get_by_id('SK_cpd03422_c0')
# Out:
# <Reaction DM_cpd03422_c0 at 0x1d0364db220>

# %%
cobra.io.write_sbml_model(model2,filename=org_name+'_model\\'+org_name+'_add_from_modelseed_222.xml')

# %%
for rxn in model.reactions:
    model.objective = model.problem.Objective(model.reactions.get_by_id('bio1_biomass').flux_expression, direction='max')

    solutionx = model.optimize()
    if solutionx.objective_value > 0:
        print(rxn.id+str(solutionx.objective_value))
# Out:
# rxn15116_c0500.0
# rxn00506_c01000.0
# rxn00536_c01000.0
# rxn00543_c01000.0
# rxn00148_c01000.0
# rxn00459_c01000.0
# rxn01106_c01000.0
# rxn00781_c01000.0
# rxn00747_c0911.1078886310904
# rxn15493_c01000.0
# rxn15364_c01000.0
# rxn00704_c01000.0
# rxn02380_c01000.0
# rxn01169_c01000.0
# rxn01977_c01000.0
# rxn15249_c01000.0
# rxn01100_c01000.0
# rxn00247_c01000.0
# rxn00175_c01000.0
# rxn00507_c01000.0
# rxn15298_c0500.00000000000006
# rxn00151_c01000.0
# rxn00147_c01000.0
# rxn00199_c01000.0
# rxn01387_c01000.0
# rxn00974_c01000.0
# rxn00248_c01000.0
# rxn00770_c01000.0
# rxn01200_c0333.3333333333334
# rxn00777_c0333.3333333333333
# rxn01116_c01000.0
# rxn15271_c01000.0
# rxn01115_c01000.0
# rxn01476_c01000.0
# rxn01975_c01000.0
# rxn29919_c0333.3333333333333
# rxn00778_c01000.0
# rxn08647_c01000.0
# rxn01187_c01000.0
# rxn11040_c01000.0
# rxn02438_c01000.0
# rxn02314_c01000.0
# rxn05929_c01000.0
# rxn00808_c01000.0
# rxn00701_c01000.0
# rxn05328_c01000.0
# rxn05323_c01000.0
# rxn05324_c01000.0
# rxn05327_c01000.0
# rxn05325_c01000.0
# rxn05326_c01000.0
# rxn05322_c01000.0
# rxn00947_c01000.0
# rxn05994_c01000.0
# rxn05995_c01000.0
# rxn02345_c01000.0
# rxn00189_c01000.0
# rxn00187_c01000.0
# rxn00192_c01000.0
# rxn00469_c01000.0
# rxn00182_c01000.0
# rxn00260_c01000.0
# rxn03004_c01000.0
# rxn00065_c01000.0
# rxn00097_c01000.0
# rxn00132_c01000.0
# rxn00515_c01000.0
# rxn01138_c01000.0
# rxn00239_c01000.0
# rxn00242_c01000.0
# rxn02449_c01000.0
# rxn00303_c01000.0
# rxn00361_c01000.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 3
#       1 for rxn in model.reactions:
#       2     model.objective = model.reactions.get_by_id(rxn.id)
# ----> 3     solutionx = model.optimize()
#       4     if solutionx.objective_value > 0:
#       5         print(rxn.id+str(solutionx.objective_value))
#
# File c:\Users\vickenlee\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\model.py:1236, in Model.optimize(self, objective_sense, raise_error)
#    1232 self.objective.direction = {"maximize": "max", "minimize": "min"}.get(
#    1233     objective_sense, original_direction
#    1234 )
#    1235 self.slim_optimize()
# -> 1236 solution = get_solution(self, raise_error=raise_error)
#    1237 self.objective.direction = original_direction
#    1238 return solution
#
# File c:\Users\vickenlee\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\solution.py:193, in get_solution(model, reactions, metabolites, raise_error)
#     191     reduced[i] = var_duals[forward] - var_duals[reverse]
#     192 met_index = []
# --> 193 constr_duals = model.solver.shadow_prices
#     194 for (i, met) in enumerate(metabolites):
#     195     met_index.append(met.id)
#
# File c:\Users\vickenlee\AppData\Local\Programs\Python\Python39\lib\site-packages\optlang\interface.py:1357, in Model.shadow_prices(self)
#    1348 @property
#    1349 def shadow_prices(self):
#    1350     """The shadow prices of model (dual values of all constraints).
#    1351
#    1352     Returns
#    1353     -------
#    1354     collections.OrderedDict
#    1355     """
#    1356     return OrderedDict(
# -> 1357         zip(self._get_constraint_names(), self._get_shadow_prices())
#    1358     )
#
# File c:\Users\vickenlee\AppData\Local\Programs\Python\Python39\lib\site-packages\optlang\cplex_interface.py:786, in Model._get_shadow_prices(self)
#     784     raise ValueError("Dual values are not well-defined for integer problems")
#     785 try:
# --> 786     return self.problem.solution.get_dual_values()
#     787 except CplexSolverError as err:
#     788     raise SolverError(str(err))
#
# File c:\Users\vickenlee\AppData\Local\Programs\Python\Python39\lib\site-packages\cplex-22.1.0.0-py3.9.egg\cplex\_internal\_subinterfaces.py:7338, in SolutionInterface.get_dual_values(self, *args)
#    7336 def getpi(a, b=self._cplex.linear_constraints.get_num() - 1):
#    7337     return CPX_PROC.getpi(self._env._e, self._cplex._lp, a, b)
# -> 7338 return apply_freeform_two_args(
#    7339     getpi, self._cplex.linear_constraints._conv, args)
#
# File c:\Users\vickenlee\AppData\Local\Programs\Python\Python39\lib\site-packages\cplex-22.1.0.0-py3.9.egg\cplex\_internal\_aux_functions.py:155, in apply_freeform_two_args(fn, conv, args, unpack_single)
#     153     raise TypeError("expecting name or index")
#     154 elif nargs == 0:
# --> 155     return fn(0)
#     156 raise WrongNumberOfArgumentsError()
#
# File c:\Users\vickenlee\AppData\Local\Programs\Python\Python39\lib\site-packages\cplex-22.1.0.0-py3.9.egg\cplex\_internal\_subinterfaces.py:7337, in SolutionInterface.get_dual_values.<locals>.getpi(a, b)
#    7336 def getpi(a, b=self._cplex.linear_constraints.get_num() - 1):
# -> 7337     return CPX_PROC.getpi(self._env._e, self._cplex._lp, a, b)
#
# File c:\Users\vickenlee\AppData\Local\Programs\Python\Python39\lib\site-packages\cplex-22.1.0.0-py3.9.egg\cplex\_internal\_procedural.py:2095, in getpi(env, lp, begin, end)
#    2093 status = CR.CPXXgetpi(env, lp, pi, begin, end)
#    2094 check_status(env, status)
# -> 2095 return LAU.array_to_list(pi, pilen)
#
# File c:\Users\vickenlee\AppData\Local\Programs\Python\Python39\lib\site-packages\cplex-22.1.0.0-py3.9.egg\cplex\_internal\_list_array_utils.py:82, in array_to_list(inputarray, length)
#      76 def array_to_list(inputarray, length):
#      77     """Converts an "array" to a list.
#      78
#      79     That is, an array created by `int_list_to_array`,
#      80     `double_list_to_array`, etc.
#      81     """
# ---> 82     return [inputarray[i] for i in range(length)]
#
# File c:\Users\vickenlee\AppData\Local\Programs\Python\Python39\lib\site-packages\cplex-22.1.0.0-py3.9.egg\cplex\_internal\_list_array_utils.py:82, in <listcomp>(.0)
#      76 def array_to_list(inputarray, length):
#      77     """Converts an "array" to a list.
#      78
#      79     That is, an array created by `int_list_to_array`,
#      80     `double_list_to_array`, etc.
#      81     """
# ---> 82     return [inputarray[i] for i in range(length)]
#
# File c:\Users\vickenlee\AppData\Local\Programs\Python\Python39\lib\site-packages\cplex-22.1.0.0-py3.9.egg\cplex\_internal\_pycplex.py:3069, in doubleCArray.__getitem__(self, index)
#    3068 def __getitem__(self, index: 'size_t') -> "double":
# -> 3069     return _pycplex_platform.doubleCArray___getitem__(self, index)
#
# KeyboardInterrupt:
