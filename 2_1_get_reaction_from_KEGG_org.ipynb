# %%
pip install requests
pip install lxml
pip install pandas
pip install openpyxl
pip install cobra

# for windows only, download the file from https://www.lfd.uci.edu/~gohlke/pythonlibs/#pyeda firstly
# pip install pyeda-0.28.0-cp37-cp37m-win_amd64.whl  
pip install modelseedpy

# %% [markdown]
# # get reaction included in KEGG pythway

# %% [markdown]
# ## get pythway ID list from kegg

# %%
import requests
from lxml import etree
org_name = 'mko'
url ='https://www.kegg.jp/kegg-bin/show_organism?menu_type=pathway_maps&org='+org_name
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'}
html = requests.get(url,headers = headers)
if not html.ok:
    raise TypeError('wrong KEGG name')
e = etree.HTML(html.text)
strain_name = e.xpath('//font[@class="title1"]/text()')
print('Organism: '+strain_name[0]+'\n')
DATA = e.xpath('//ul/a/@href')
pathway_ID = [i.replace('/pathway/','') for i in DATA]
print(str(len(pathway_ID))+' pathway maps are found')
# Out:
# Organism: Methylomonas koyamae
#
# 112 pathway maps are found

# %% [markdown]
# ## download xml files

# %%
import re
import os
import requests

# create folder
path=".\\"+org_name
if not os.path.exists(path):
    os.makedirs(path)
    os.makedirs(path+'_model')
#download xml   
i = 1
for ID in pathway_ID:
    downloadurl = 'https://www.kegg.jp/kegg-bin/download?entry='+ID+'&format=kgml'
    headers={'Referer':'https://www.kegg.jp/pathway/'+ID,'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'}
    xml=requests.get(downloadurl,headers = headers)
    if not xml.ok:
        print(ID+'.xml can not be found.   '+str(i)+'/'+ str(len(pathway_ID)))
        i+=1
        continue
    with open(path+'\\'+ID+".xml","wb") as code:
        code.write(xml.content)
    print(ID+'.xml write secceed.   '+str(i)+'/'+ str(len(pathway_ID)))
    i+=1
# Out:
# mko01100.xml can not be found.   1/112
# mko01110.xml can not be found.   2/112
# mko01120.xml can not be found.   3/112
# mko01200.xml can not be found.   4/112
# mko01210.xml can not be found.   5/112
# mko01212.xml can not be found.   6/112
# mko01230.xml can not be found.   7/112
# mko01232.xml can not be found.   8/112
# mko01250.xml can not be found.   9/112
# mko01240.xml can not be found.   10/112
# mko01220.xml can not be found.   11/112
# mko00010.xml write secceed.   12/112
# mko00020.xml write secceed.   13/112
# mko00030.xml write secceed.   14/112
# mko00040.xml write secceed.   15/112
# mko00051.xml write secceed.   16/112
# mko00052.xml write secceed.   17/112
# mko00053.xml write secceed.   18/112
# mko00500.xml write secceed.   19/112
# mko00520.xml write secceed.   20/112
# mko00620.xml write secceed.   21/112
# mko00630.xml write secceed.   22/112
# mko00640.xml write secceed.   23/112
# mko00650.xml write secceed.   24/112
# mko00660.xml write secceed.   25/112
# mko00562.xml write secceed.   26/112
# mko00190.xml write secceed.   27/112
# mko00680.xml write secceed.   28/112
# mko00910.xml write secceed.   29/112
# mko00920.xml write secceed.   30/112
# mko00061.xml write secceed.   31/112
# mko00071.xml write secceed.   32/112
# mko00561.xml write secceed.   33/112
# mko00564.xml write secceed.   34/112
# mko00230.xml write secceed.   35/112
# mko00240.xml write secceed.   36/112
# mko00250.xml write secceed.   37/112
# mko00260.xml write secceed.   38/112
# mko00270.xml write secceed.   39/112
# mko00280.xml write secceed.   40/112
# mko00290.xml write secceed.   41/112
# mko00300.xml write secceed.   42/112
# mko00310.xml write secceed.   43/112
# mko00220.xml write secceed.   44/112
# mko00330.xml write secceed.   45/112
# mko00340.xml write secceed.   46/112
# mko00350.xml write secceed.   47/112
# mko00360.xml write secceed.   48/112
# mko00380.xml write secceed.   49/112
# mko00400.xml write secceed.   50/112
# mko00410.xml write secceed.   51/112
# mko00430.xml write secceed.   52/112
# mko00450.xml write secceed.   53/112
# mko00460.xml write secceed.   54/112
# mko00470.xml write secceed.   55/112
# mko00480.xml write secceed.   56/112
# mko00540.xml write secceed.   57/112
# mko00541.xml write secceed.   58/112
# mko00550.xml write secceed.   59/112
# mko00552.xml write secceed.   60/112
# mko00543.xml write secceed.   61/112
# mko00730.xml write secceed.   62/112
# mko00740.xml write secceed.   63/112
# mko00750.xml write secceed.   64/112
# mko00760.xml write secceed.   65/112
# mko00770.xml write secceed.   66/112
# mko00780.xml write secceed.   67/112
# mko00785.xml write secceed.   68/112
# mko00790.xml write secceed.   69/112
# mko00670.xml write secceed.   70/112
# mko00860.xml write secceed.   71/112
# mko00130.xml write secceed.   72/112
# mko00900.xml write secceed.   73/112
# mko00909.xml write secceed.   74/112
# mko00906.xml write secceed.   75/112
# mko00523.xml write secceed.   76/112
# mko00946.xml write secceed.   77/112
# mko00311.xml write secceed.   78/112
# mko00332.xml write secceed.   79/112
# mko00261.xml write secceed.   80/112
# mko00521.xml write secceed.   81/112
# mko00525.xml write secceed.   82/112
# mko00401.xml write secceed.   83/112
# mko00405.xml write secceed.   84/112
# mko00999.xml write secceed.   85/112
# mko00627.xml write secceed.   86/112
# mko00364.xml write secceed.   87/112
# mko00625.xml write secceed.   88/112
# mko00361.xml write secceed.   89/112
# mko00623.xml write secceed.   90/112
# mko00791.xml write secceed.   91/112
# mko00626.xml write secceed.   92/112
# mko03020.xml write secceed.   93/112
# mko03010.xml write secceed.   94/112
# mko00970.xml write secceed.   95/112
# mko03060.xml write secceed.   96/112
# mko04122.xml write secceed.   97/112
# mko03018.xml write secceed.   98/112
# mko03030.xml write secceed.   99/112
# mko03410.xml write secceed.   100/112
# mko03420.xml write secceed.   101/112
# mko03430.xml write secceed.   102/112
# mko03440.xml write secceed.   103/112
# mko02010.xml write secceed.   104/112
# mko03070.xml write secceed.   105/112
# mko02020.xml write secceed.   106/112
# mko02024.xml write secceed.   107/112
# mko02030.xml write secceed.   108/112
# mko02040.xml write secceed.   109/112
# mko01501.xml write secceed.   110/112
# mko01502.xml write secceed.   111/112
# mko01503.xml write secceed.   112/112

# %% [markdown]
# ## get xml detail

# %%
from Bio.KEGG.KGML.KGML_parser import read
pathway = read(open('mbry/mbry00010.xml', 'r'))

# %%
org_name = 'mbry'

# %%
import os
import xml.dom.minidom as xo
import pandas as pd

path=".\\"+org_name
xmls = [path+'\\'+i for i in os.listdir(path) if i.endswith('.xml')]
df_xmlentry = pd.DataFrame(columns=["pathway_ID", "pathway_title", "entry_id", "entry_name","entry_type","entry_reaction","entry_link"])
df_xmlreaction = pd.DataFrame(columns=["reaction_ID", "reaction_name", "reaction_type", "reaction_substrates","reaction_products"])
i=1
for xml in xmls:
    domtree = xo.parse(xml)
    pathway = domtree.documentElement
    pathway_ID = pathway.getAttribute("name")
    pathway_org = pathway.getAttribute("org")
    pathway_title = pathway.getAttribute("title")
    entrys = pathway.getElementsByTagName("entry")
    reactions = pathway.getElementsByTagName("reaction")
    for entry in entrys:
        entry_id= pathway_ID+'-'+entry.getAttribute("id")
        entry_name = entry.getAttribute("name")
        entry_type = entry.getAttribute("type")
        entry_reaction = entry.getAttribute("reaction")
        entry_link = entry.getAttribute("link")
        data = [pathway_ID,pathway_title,entry_id,entry_name,entry_type,entry_reaction,entry_link]
        df_xmlentry.loc[len(df_xmlentry.index)]=data
        #graphics = entry.getElementsByTagName('graphics')[0]
        #graphics_name = graphics.getAttribute("name")
    for reaction in reactions:
        reaction_id = pathway_ID+'-'+reaction.getAttribute("id")
        reaction_name = reaction.getAttribute("name")
        reaction_type = reaction.getAttribute("type")
        substrates = reaction.getElementsByTagName("substrate")
        reaction_substrates = [substrate.getAttribute("name") for substrate in substrates]
        products = reaction.getElementsByTagName("product")
        reaction_products = [product.getAttribute("name") for product in products]
        data = [reaction_id, reaction_name, reaction_type, str(reaction_substrates),str(reaction_products)]
        df_xmlreaction.loc[len(df_xmlreaction.index)]=data
    print('File:',xml,'done.  ',i,'/',len(xmls))
    i+=1

df_r = df_xmlreaction.rename(columns={'reaction_name':'entry_reaction'}).drop(columns='reaction_ID')
df_org_reaction = pd.merge(df_xmlentry.query('entry_type == "gene" and entry_reaction != ""'),df_r,how='left', on='entry_reaction').drop_duplicates(subset=['entry_reaction'])

df_org_reaction.to_excel(org_name+'_model\\'+org_name+'_KEGG_pathway_reaction.xlsx', sheet_name='Sheet1', header=True)
# Out:
# File: .\mbry\mbry00010.xml done.   1 / 107
# File: .\mbry\mbry00020.xml done.   2 / 107
# File: .\mbry\mbry00030.xml done.   3 / 107
# File: .\mbry\mbry00040.xml done.   4 / 107
# File: .\mbry\mbry00051.xml done.   5 / 107
# File: .\mbry\mbry00052.xml done.   6 / 107
# File: .\mbry\mbry00053.xml done.   7 / 107
# File: .\mbry\mbry00061.xml done.   8 / 107
# File: .\mbry\mbry00071.xml done.   9 / 107
# File: .\mbry\mbry00130.xml done.   10 / 107
# File: .\mbry\mbry00190.xml done.   11 / 107
# File: .\mbry\mbry00220.xml done.   12 / 107
# File: .\mbry\mbry00230.xml done.   13 / 107
# File: .\mbry\mbry00240.xml done.   14 / 107
# File: .\mbry\mbry00250.xml done.   15 / 107
# File: .\mbry\mbry00260.xml done.   16 / 107
# File: .\mbry\mbry00261.xml done.   17 / 107
# File: .\mbry\mbry00270.xml done.   18 / 107
# File: .\mbry\mbry00280.xml done.   19 / 107
# File: .\mbry\mbry00281.xml done.   20 / 107
# File: .\mbry\mbry00290.xml done.   21 / 107
# File: .\mbry\mbry00300.xml done.   22 / 107
# File: .\mbry\mbry00310.xml done.   23 / 107
# File: .\mbry\mbry00330.xml done.   24 / 107
# File: .\mbry\mbry00332.xml done.   25 / 107
# File: .\mbry\mbry00340.xml done.   26 / 107
# File: .\mbry\mbry00350.xml done.   27 / 107
# File: .\mbry\mbry00360.xml done.   28 / 107
# File: .\mbry\mbry00361.xml done.   29 / 107
# File: .\mbry\mbry00362.xml done.   30 / 107
# File: .\mbry\mbry00364.xml done.   31 / 107
# File: .\mbry\mbry00380.xml done.   32 / 107
# File: .\mbry\mbry00400.xml done.   33 / 107
# File: .\mbry\mbry00401.xml done.   34 / 107
# File: .\mbry\mbry00410.xml done.   35 / 107
# File: .\mbry\mbry00430.xml done.   36 / 107
# File: .\mbry\mbry00450.xml done.   37 / 107
# File: .\mbry\mbry00460.xml done.   38 / 107
# File: .\mbry\mbry00470.xml done.   39 / 107
# File: .\mbry\mbry00480.xml done.   40 / 107
# File: .\mbry\mbry00500.xml done.   41 / 107
# File: .\mbry\mbry00520.xml done.   42 / 107
# File: .\mbry\mbry00521.xml done.   43 / 107
# File: .\mbry\mbry00523.xml done.   44 / 107
# File: .\mbry\mbry00525.xml done.   45 / 107
# File: .\mbry\mbry00540.xml done.   46 / 107
# File: .\mbry\mbry00541.xml done.   47 / 107
# File: .\mbry\mbry00543.xml done.   48 / 107
# File: .\mbry\mbry00550.xml done.   49 / 107
# File: .\mbry\mbry00552.xml done.   50 / 107
# File: .\mbry\mbry00561.xml done.   51 / 107
# File: .\mbry\mbry00562.xml done.   52 / 107
# File: .\mbry\mbry00564.xml done.   53 / 107
# File: .\mbry\mbry00600.xml done.   54 / 107
# File: .\mbry\mbry00620.xml done.   55 / 107
# File: .\mbry\mbry00623.xml done.   56 / 107
# File: .\mbry\mbry00625.xml done.   57 / 107
# File: .\mbry\mbry00626.xml done.   58 / 107
# File: .\mbry\mbry00627.xml done.   59 / 107
# File: .\mbry\mbry00630.xml done.   60 / 107
# File: .\mbry\mbry00640.xml done.   61 / 107
# File: .\mbry\mbry00643.xml done.   62 / 107
# File: .\mbry\mbry00650.xml done.   63 / 107
# File: .\mbry\mbry00660.xml done.   64 / 107
# File: .\mbry\mbry00670.xml done.   65 / 107
# File: .\mbry\mbry00680.xml done.   66 / 107
# File: .\mbry\mbry00710.xml done.   67 / 107
# File: .\mbry\mbry00730.xml done.   68 / 107
# File: .\mbry\mbry00740.xml done.   69 / 107
# File: .\mbry\mbry00750.xml done.   70 / 107
# File: .\mbry\mbry00760.xml done.   71 / 107
# File: .\mbry\mbry00770.xml done.   72 / 107
# File: .\mbry\mbry00780.xml done.   73 / 107
# File: .\mbry\mbry00785.xml done.   74 / 107
# File: .\mbry\mbry00790.xml done.   75 / 107
# File: .\mbry\mbry00860.xml done.   76 / 107
# File: .\mbry\mbry00900.xml done.   77 / 107
# File: .\mbry\mbry00903.xml done.   78 / 107
# File: .\mbry\mbry00906.xml done.   79 / 107
# File: .\mbry\mbry00910.xml done.   80 / 107
# File: .\mbry\mbry00920.xml done.   81 / 107
# File: .\mbry\mbry00930.xml done.   82 / 107
# File: .\mbry\mbry00946.xml done.   83 / 107
# File: .\mbry\mbry00970.xml done.   84 / 107
# File: .\mbry\mbry00999.xml done.   85 / 107
# File: .\mbry\mbry01040.xml done.   86 / 107
# File: .\mbry\mbry01501.xml done.   87 / 107
# File: .\mbry\mbry01502.xml done.   88 / 107
# File: .\mbry\mbry01503.xml done.   89 / 107
# File: .\mbry\mbry02010.xml done.   90 / 107
# File: .\mbry\mbry02020.xml done.   91 / 107
# File: .\mbry\mbry02024.xml done.   92 / 107
# File: .\mbry\mbry02030.xml done.   93 / 107
# File: .\mbry\mbry02040.xml done.   94 / 107
# File: .\mbry\mbry02060.xml done.   95 / 107
# File: .\mbry\mbry03010.xml done.   96 / 107
# File: .\mbry\mbry03018.xml done.   97 / 107
# File: .\mbry\mbry03020.xml done.   98 / 107
# File: .\mbry\mbry03030.xml done.   99 / 107
# File: .\mbry\mbry03060.xml done.   100 / 107
# File: .\mbry\mbry03070.xml done.   101 / 107
# File: .\mbry\mbry03410.xml done.   102 / 107
# File: .\mbry\mbry03420.xml done.   103 / 107
# File: .\mbry\mbry03430.xml done.   104 / 107
# File: .\mbry\mbry03440.xml done.   105 / 107
# File: .\mbry\mbry03450.xml done.   106 / 107
# File: .\mbry\mbry04122.xml done.   107 / 107

# %% [markdown]
# ## data clean

# %%
import pandas as pd

df_org_reaction = pd.read_excel(org_name+'_model\\'+org_name+'_KEGG_pathway_reaction.xlsx')  
titlename= ['entry_name','pathway_title','reaction_type','reaction_substrates','reaction_products']
df_gene = df_org_reaction[['entry_reaction']+titlename]
df_reaction_list = pd.concat([df_gene['entry_reaction'].str.split('rn:',expand=True).iloc[:,1:],df_gene[titlename]],axis=1)
df_reaction_melt = df_reaction_list.melt(id_vars = titlename, value_vars = [1,2,3,4],var_name = 'r',value_name = 'Kegg_ID').drop(['r'],axis = 1).dropna(subset=['Kegg_ID'])
df_reaction_melt['Kegg_ID'] = df_reaction_melt['Kegg_ID'].str.strip()
df_reaction = df_reaction_melt.drop_duplicates(subset=['Kegg_ID'])[['Kegg_ID']+titlename]
df_reaction.to_excel(org_name+'_model\\'+org_name+'_clean_kegg_reaction.xlsx', sheet_name='Sheet1', header=True)
