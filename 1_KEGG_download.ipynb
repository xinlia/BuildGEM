# %% [markdown]
# # Download global KEGG pathway database

# %%
import os
if not os.path.exists('KEGG'):
    os.makedirs('KEGG')

# %% [markdown]
# ##  Download KEGG pathway id/names

# %%
import requests
from lxml import etree
import json

pathways_name_dir = {}

url = 'https://www.kegg.jp/kegg/pathway.html'
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'}
html = requests.get(url,headers = headers)
e = etree.HTML(html.text)
idlist = e.xpath('//div[@class="list"]//dt/text()')
print('%d pathways ID found.'%len(idlist))
namelist = e.xpath('//div[@class="list"]//dd/a[1]/text()')
print('%d pathways name found.'%len(namelist))
if len(idlist) == len(namelist):
    for i in range(len(idlist)):
        pathways_name_dir['map'+idlist[i].strip()] = namelist[i].strip()
else:
    print('Error!')

with open('KEGG\\KEGG_pathways_name.json', 'w') as f:
    f.write(json.dumps(pathways_name_dir))
f.close()

# %% [markdown]
# ## Download KO, EC, R entries in KEGG pathways

# %%
import pandas as pd
import requests
from lxml import etree
import json

with open('KEGG\\KEGG_pathways_name.json', 'r') as f:
    pathways_name_dir = json.load(f)
f.close()

pathways_list = [i for i in pathways_name_dir.keys()]

KEGG_pathways_entrys = pd.DataFrame(columns=['pw_ID','pw_name','coords','href','title'])

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'}
m = 1
for pathway in pathways_list:
    pathway_name = pathways_name_dir[pathway]
    KEGG_pathway = requests.get('https://www.kegg.jp/pathway/'+pathway,headers = headers)
    e = etree.HTML(KEGG_pathway.text)
    hreflist = e.xpath('//map[@id="mapdata"]/area/@href')
    coordslist = e.xpath('//map[@id="mapdata"]/area/@coords')
    entrylist = e.xpath('//map[@id="mapdata"]/area/@title')
    print('found %d entries in %s'%(len(hreflist),pathway))
    if not len(hreflist) == len(entrylist):
        print(pathway,'Error!')
        continue
    for i in range(len(hreflist)):
        href = hreflist[i]
        coords = coordslist[i]
        title = entrylist[i]
        KEGG_pathways_entrys.loc[len(KEGG_pathways_entrys.index)]=[pathway,pathway_name,coords,href,title]

    print('map:'+pathway+'done!    '+str(m)+' / '+str(len(pathways_list)))
    m=m+1

KEGG_pathways_entrys.to_csv('KEGG\\KEGG_pathways_entrys.txt', header=True, index=False,sep='\t')
# Out:
# found 7743 entries in map01100
# map:map01100done!    1 / 563
# found 4836 entries in map01110
# map:map01110done!    2 / 563
# found 2462 entries in map01120
# map:map01120done!    3 / 563
# found 292 entries in map01200
# map:map01200done!    4 / 563
# found 296 entries in map01210
# map:map01210done!    5 / 563
# found 333 entries in map01212
# map:map01212done!    6 / 563
# found 288 entries in map01230
# map:map01230done!    7 / 563
# found 181 entries in map01232
# map:map01232done!    8 / 563
# found 414 entries in map01250
# map:map01250done!    9 / 563
# found 669 entries in map01240
# map:map01240done!    10 / 563
# found 590 entries in map01220
# map:map01220done!    11 / 563
# found 101 entries in map00010
# map:map00010done!    12 / 563
# found 71 entries in map00020
# map:map00020done!    13 / 563
# found 118 entries in map00030
# map:map00030done!    14 / 563
# found 160 entries in map00040
# map:map00040done!    15 / 563
# found 156 entries in map00051
# map:map00051done!    16 / 563
# found 117 entries in map00052
# map:map00052done!    17 / 563
# found 142 entries in map00053
# map:map00053done!    18 / 563
# found 148 entries in map00500
# map:map00500done!    19 / 563
# found 314 entries in map00520
# map:map00520done!    20 / 563
# found 138 entries in map00620
# map:map00620done!    21 / 563
# found 173 entries in map00630
# map:map00630done!    22 / 563
# found 125 entries in map00640
# map:map00640done!    23 / 563
# found 128 entries in map00650
# map:map00650done!    24 / 563
# found 82 entries in map00660
# map:map00660done!    25 / 563
# found 116 entries in map00562
# map:map00562done!    26 / 563
# found 224 entries in map00190
# map:map00190done!    27 / 563
# found 85 entries in map00195
# map:map00195done!    28 / 563
# found 39 entries in map00196
# map:map00196done!    29 / 563
# found 67 entries in map00710
# map:map00710done!    30 / 563
# found 112 entries in map00720
# map:map00720done!    31 / 563
# found 224 entries in map00680
# map:map00680done!    32 / 563
# found 119 entries in map00910
# map:map00910done!    33 / 563
# found 134 entries in map00920
# map:map00920done!    34 / 563
# found 325 entries in map00061
# map:map00061done!    35 / 563
# found 98 entries in map00062
# map:map00062done!    36 / 563
# found 153 entries in map00071
# map:map00071done!    37 / 563
# found 77 entries in map00073
# map:map00073done!    38 / 563
# found 132 entries in map00100
# map:map00100done!    39 / 563
# found 107 entries in map00120
# map:map00120done!    40 / 563
# found 83 entries in map00121
# map:map00121done!    41 / 563
# found 230 entries in map00140
# map:map00140done!    42 / 563
# found 95 entries in map00561
# map:map00561done!    43 / 563
# found 166 entries in map00564
# map:map00564done!    44 / 563
# found 59 entries in map00565
# map:map00565done!    45 / 563
# found 104 entries in map00600
# map:map00600done!    46 / 563
# found 163 entries in map00590
# map:map00590done!    47 / 563
# found 57 entries in map00591
# map:map00591done!    48 / 563
# found 76 entries in map00592
# map:map00592done!    49 / 563
# found 293 entries in map01040
# map:map01040done!    50 / 563
# found 300 entries in map00230
# map:map00230done!    51 / 563
# found 202 entries in map00240
# map:map00240done!    52 / 563
# found 112 entries in map00250
# map:map00250done!    53 / 563
# found 153 entries in map00260
# map:map00260done!    54 / 563
# found 201 entries in map00270
# map:map00270done!    55 / 563
# found 116 entries in map00280
# map:map00280done!    56 / 563
# found 55 entries in map00290
# map:map00290done!    57 / 563
# found 85 entries in map00300
# map:map00300done!    58 / 563
# found 140 entries in map00310
# map:map00310done!    59 / 563
# found 65 entries in map00220
# map:map00220done!    60 / 563
# found 189 entries in map00330
# map:map00330done!    61 / 563
# found 107 entries in map00340
# map:map00340done!    62 / 563
# found 212 entries in map00350
# map:map00350done!    63 / 563
# found 130 entries in map00360
# map:map00360done!    64 / 563
# found 198 entries in map00380
# map:map00380done!    65 / 563
# found 117 entries in map00400
# map:map00400done!    66 / 563
# found 84 entries in map00410
# map:map00410done!    67 / 563
# found 59 entries in map00430
# map:map00430done!    68 / 563
# found 116 entries in map00440
# map:map00440done!    69 / 563
# found 54 entries in map00450
# map:map00450done!    70 / 563
# found 121 entries in map00460
# map:map00460done!    71 / 563
# found 166 entries in map00470
# map:map00470done!    72 / 563
# found 117 entries in map00480
# map:map00480done!    73 / 563
# found 123 entries in map00510
# map:map00510done!    74 / 563
# found 196 entries in map00513
# map:map00513done!    75 / 563
# found 58 entries in map00512
# map:map00512done!    76 / 563
# found 91 entries in map00515
# map:map00515done!    77 / 563
# found 46 entries in map00514
# map:map00514done!    78 / 563
# found 44 entries in map00532
# map:map00532done!    79 / 563
# found 51 entries in map00534
# map:map00534done!    80 / 563
# found 27 entries in map00533
# map:map00533done!    81 / 563
# found 84 entries in map00531
# map:map00531done!    82 / 563
# found 59 entries in map00563
# map:map00563done!    83 / 563
# found 186 entries in map00601
# map:map00601done!    84 / 563
# found 66 entries in map00603
# map:map00603done!    85 / 563
# found 73 entries in map00604
# map:map00604done!    86 / 563
# found 27 entries in map00511
# map:map00511done!    87 / 563
# found 155 entries in map00540
# map:map00540done!    88 / 563
# found 86 entries in map00542
# map:map00542done!    89 / 563
# found 184 entries in map00541
# map:map00541done!    90 / 563
# found 74 entries in map00550
# map:map00550done!    91 / 563
# found 213 entries in map00552
# map:map00552done!    92 / 563
# found 81 entries in map00571
# map:map00571done!    93 / 563
# found 90 entries in map00572
# map:map00572done!    94 / 563
# found 167 entries in map00543
# map:map00543done!    95 / 563
# found 78 entries in map00730
# map:map00730done!    96 / 563
# found 66 entries in map00740
# map:map00740done!    97 / 563
# found 78 entries in map00750
# map:map00750done!    98 / 563
# found 147 entries in map00760
# map:map00760done!    99 / 563
# found 76 entries in map00770
# map:map00770done!    100 / 563
# found 69 entries in map00780
# map:map00780done!    101 / 563
# found 100 entries in map00785
# map:map00785done!    102 / 563
# found 137 entries in map00790
# map:map00790done!    103 / 563
# found 45 entries in map00670
# map:map00670done!    104 / 563
# found 73 entries in map00830
# map:map00830done!    105 / 563
# found 324 entries in map00860
# map:map00860done!    106 / 563
# found 155 entries in map00130
# map:map00130done!    107 / 563
# found 116 entries in map00900
# map:map00900done!    108 / 563
# found 136 entries in map00902
# map:map00902done!    109 / 563
# found 178 entries in map00909
# map:map00909done!    110 / 563
# found 264 entries in map00904
# map:map00904done!    111 / 563
# found 291 entries in map00906
# map:map00906done!    112 / 563
# found 72 entries in map00905
# map:map00905done!    113 / 563
# found 57 entries in map00981
# map:map00981done!    114 / 563
# found 85 entries in map00908
# map:map00908done!    115 / 563
# found 96 entries in map00903
# map:map00903done!    116 / 563
# found 111 entries in map00907
# map:map00907done!    117 / 563
# found 192 entries in map01052
# map:map01052done!    118 / 563
# found 171 entries in map00522
# map:map00522done!    119 / 563
# found 82 entries in map01051
# map:map01051done!    120 / 563
# found 160 entries in map01059
# map:map01059done!    121 / 563
# found 42 entries in map01056
# map:map01056done!    122 / 563
# found 280 entries in map01057
# map:map01057done!    123 / 563
# found 44 entries in map00253
# map:map00253done!    124 / 563
# found 125 entries in map00523
# map:map00523done!    125 / 563
# found 78 entries in map01054
# map:map01054done!    126 / 563
# found 72 entries in map01053
# map:map01053done!    127 / 563
# found 56 entries in map01055
# map:map01055done!    128 / 563
# found 149 entries in map00940
# map:map00940done!    129 / 563
# found 61 entries in map00945
# map:map00945done!    130 / 563
# found 180 entries in map00941
# map:map00941done!    131 / 563
# found 106 entries in map00944
# map:map00944done!    132 / 563
# found 134 entries in map00942
# map:map00942done!    133 / 563
# found 137 entries in map00943
# map:map00943done!    134 / 563
# found 80 entries in map00946
# map:map00946done!    135 / 563
# found 168 entries in map00901
# map:map00901done!    136 / 563
# found 75 entries in map00403
# map:map00403done!    137 / 563
# found 288 entries in map00950
# map:map00950done!    138 / 563
# found 158 entries in map00960
# map:map00960done!    139 / 563
# found 141 entries in map00996
# map:map00996done!    140 / 563
# found 60 entries in map00232
# map:map00232done!    141 / 563
# found 59 entries in map00965
# map:map00965done!    142 / 563
# found 142 entries in map00966
# map:map00966done!    143 / 563
# found 19 entries in map00402
# map:map00402done!    144 / 563
# found 39 entries in map00311
# map:map00311done!    145 / 563
# found 66 entries in map00332
# map:map00332done!    146 / 563
# found 77 entries in map00261
# map:map00261done!    147 / 563
# found 20 entries in map00331
# map:map00331done!    148 / 563
# found 54 entries in map00521
# map:map00521done!    149 / 563
# found 165 entries in map00524
# map:map00524done!    150 / 563
# found 74 entries in map00525
# map:map00525done!    151 / 563
# found 80 entries in map00401
# map:map00401done!    152 / 563
# found 98 entries in map00404
# map:map00404done!    153 / 563
# found 63 entries in map00405
# map:map00405done!    154 / 563
# found 36 entries in map00333
# map:map00333done!    155 / 563
# found 57 entries in map00254
# map:map00254done!    156 / 563
# found 200 entries in map00998
# map:map00998done!    157 / 563
# found 293 entries in map00999
# map:map00999done!    158 / 563
# found 118 entries in map00997
# map:map00997done!    159 / 563
# found 176 entries in map00362
# map:map00362done!    160 / 563
# found 199 entries in map00627
# map:map00627done!    161 / 563
# found 71 entries in map00364
# map:map00364done!    162 / 563
# found 99 entries in map00625
# map:map00625done!    163 / 563
# found 178 entries in map00361
# map:map00361done!    164 / 563
# found 104 entries in map00623
# map:map00623done!    165 / 563
# found 84 entries in map00622
# map:map00622done!    166 / 563
# found 65 entries in map00633
# map:map00633done!    167 / 563
# found 33 entries in map00642
# map:map00642done!    168 / 563
# found 54 entries in map00643
# map:map00643done!    169 / 563
# found 52 entries in map00791
# map:map00791done!    170 / 563
# found 60 entries in map00930
# map:map00930done!    171 / 563
# found 52 entries in map00363
# map:map00363done!    172 / 563
# found 104 entries in map00621
# map:map00621done!    173 / 563
# found 121 entries in map00626
# map:map00626done!    174 / 563
# found 227 entries in map00624
# map:map00624done!    175 / 563
# found 21 entries in map00365
# map:map00365done!    176 / 563
# found 39 entries in map00984
# map:map00984done!    177 / 563
# found 255 entries in map00980
# map:map00980done!    178 / 563
# found 189 entries in map00982
# map:map00982done!    179 / 563
# found 110 entries in map00983
# map:map00983done!    180 / 563
# found 22 entries in map01010
# map:map01010done!    181 / 563
# found 168 entries in map01060
# map:map01060done!    182 / 563
# found 115 entries in map01061
# map:map01061done!    183 / 563
# found 122 entries in map01062
# map:map01062done!    184 / 563
# found 149 entries in map01063
# map:map01063done!    185 / 563
# found 74 entries in map01064
# map:map01064done!    186 / 563
# found 42 entries in map01065
# map:map01065done!    187 / 563
# found 54 entries in map01066
# map:map01066done!    188 / 563
# found 88 entries in map01070
# map:map01070done!    189 / 563
# found 64 entries in map03020
# map:map03020done!    190 / 563
# found 38 entries in map03022
# map:map03022done!    191 / 563
# found 91 entries in map03040
# map:map03040done!    192 / 563
# found 143 entries in map03010
# map:map03010done!    193 / 563
# found 118 entries in map00970
# map:map00970done!    194 / 563
# found 79 entries in map03013
# map:map03013done!    195 / 563
# found 66 entries in map03015
# map:map03015done!    196 / 563
# found 67 entries in map03008
# map:map03008done!    197 / 563
# found 39 entries in map03060
# map:map03060done!    198 / 563
# found 122 entries in map04141
# map:map04141done!    199 / 563
# found 36 entries in map04130
# map:map04130done!    200 / 563
# found 115 entries in map04120
# map:map04120done!    201 / 563
# found 61 entries in map04122
# map:map04122done!    202 / 563
# found 56 entries in map03050
# map:map03050done!    203 / 563
# found 79 entries in map03018
# map:map03018done!    204 / 563
# found 65 entries in map03030
# map:map03030done!    205 / 563
# found 65 entries in map03410
# map:map03410done!    206 / 563
# found 56 entries in map03420
# map:map03420done!    207 / 563
# found 32 entries in map03430
# map:map03430done!    208 / 563
# found 69 entries in map03440
# map:map03440done!    209 / 563
# found 21 entries in map03450
# map:map03450done!    210 / 563
# found 52 entries in map03460
# map:map03460done!    211 / 563
# found 172 entries in map03230
# map:map03230done!    212 / 563
# found 147 entries in map03240
# map:map03240done!    213 / 563
# found 84 entries in map03250
# map:map03250done!    214 / 563
# found 27 entries in map03260
# map:map03260done!    215 / 563
# found 32 entries in map03262
# map:map03262done!    216 / 563
# found 17 entries in map03261
# map:map03261done!    217 / 563
# found 19 entries in map03263
# map:map03263done!    218 / 563
# found 16 entries in map03264
# map:map03264done!    219 / 563
# found 9 entries in map03265
# map:map03265done!    220 / 563
# found 37 entries in map03266
# map:map03266done!    221 / 563
# found 53 entries in map03268
# map:map03268done!    222 / 563
# found 20 entries in map03267
# map:map03267done!    223 / 563
# found 632 entries in map02010
# map:map02010done!    224 / 563
# found 142 entries in map02060
# map:map02060done!    225 / 563
# found 81 entries in map03070
# map:map03070done!    226 / 563
# found 589 entries in map02020
# map:map02020done!    227 / 563
# found 132 entries in map04010
# map:map04010done!    228 / 563
# found 91 entries in map04013
# map:map04013done!    229 / 563
# found 73 entries in map04016
# map:map04016done!    230 / 563
# found 119 entries in map04011
# map:map04011done!    231 / 563
# found 74 entries in map04012
# map:map04012done!    232 / 563
# found 108 entries in map04014
# map:map04014done!    233 / 563
# found 100 entries in map04015
# map:map04015done!    234 / 563
# found 101 entries in map04310
# map:map04310done!    235 / 563
# found 34 entries in map04330
# map:map04330done!    236 / 563
# found 62 entries in map04340
# map:map04340done!    237 / 563
# found 45 entries in map04341
# map:map04341done!    238 / 563
# found 90 entries in map04350
# map:map04350done!    239 / 563
# found 98 entries in map04390
# map:map04390done!    240 / 563
# found 74 entries in map04391
# map:map04391done!    241 / 563
# found 51 entries in map04392
# map:map04392done!    242 / 563
# found 40 entries in map04370
# map:map04370done!    243 / 563
# found 83 entries in map04371
# map:map04371done!    244 / 563
# found 92 entries in map04630
# map:map04630done!    245 / 563
# found 155 entries in map04064
# map:map04064done!    246 / 563
# found 108 entries in map04668
# map:map04668done!    247 / 563
# found 89 entries in map04066
# map:map04066done!    248 / 563
# found 98 entries in map04068
# map:map04068done!    249 / 563
# found 85 entries in map04020
# map:map04020done!    250 / 563
# found 83 entries in map04070
# map:map04070done!    251 / 563
# found 83 entries in map04072
# map:map04072done!    252 / 563
# found 88 entries in map04071
# map:map04071done!    253 / 563
# found 138 entries in map04024
# map:map04024done!    254 / 563
# found 89 entries in map04022
# map:map04022done!    255 / 563
# found 112 entries in map04151
# map:map04151done!    256 / 563
# found 106 entries in map04152
# map:map04152done!    257 / 563
# found 88 entries in map04150
# map:map04150done!    258 / 563
# found 68 entries in map04075
# map:map04075done!    259 / 563
# found 196 entries in map04080
# map:map04080done!    260 / 563
# found 376 entries in map04060
# map:map04060done!    261 / 563
# found 259 entries in map04061
# map:map04061done!    262 / 563
# found 126 entries in map04512
# map:map04512done!    263 / 563
# found 265 entries in map04514
# map:map04514done!    264 / 563
# found 137 entries in map04144
# map:map04144done!    265 / 563
# found 83 entries in map04145
# map:map04145done!    266 / 563
# found 86 entries in map04142
# map:map04142done!    267 / 563
# found 74 entries in map04146
# map:map04146done!    268 / 563
# found 129 entries in map04140
# map:map04140done!    269 / 563
# found 87 entries in map04138
# map:map04138done!    270 / 563
# found 34 entries in map04136
# map:map04136done!    271 / 563
# found 51 entries in map04137
# map:map04137done!    272 / 563
# found 39 entries in map04139
# map:map04139done!    273 / 563
# found 117 entries in map04110
# map:map04110done!    274 / 563
# found 136 entries in map04111
# map:map04111done!    275 / 563
# found 36 entries in map04112
# map:map04112done!    276 / 563
# found 110 entries in map04113
# map:map04113done!    277 / 563
# found 80 entries in map04114
# map:map04114done!    278 / 563
# found 119 entries in map04210
# map:map04210done!    279 / 563
# found 77 entries in map04214
# map:map04214done!    280 / 563
# found 51 entries in map04215
# map:map04215done!    281 / 563
# found 76 entries in map04216
# map:map04216done!    282 / 563
# found 93 entries in map04217
# map:map04217done!    283 / 563
# found 70 entries in map04115
# map:map04115done!    284 / 563
# found 110 entries in map04218
# map:map04218done!    285 / 563
# found 73 entries in map04510
# map:map04510done!    286 / 563
# found 96 entries in map04520
# map:map04520done!    287 / 563
# found 134 entries in map04530
# map:map04530done!    288 / 563
# found 60 entries in map04540
# map:map04540done!    289 / 563
# found 107 entries in map04550
# map:map04550done!    290 / 563
# found 409 entries in map02024
# map:map02024done!    291 / 563
# found 81 entries in map05111
# map:map05111done!    292 / 563
# found 80 entries in map02025
# map:map02025done!    293 / 563
# found 76 entries in map02026
# map:map02026done!    294 / 563
# found 34 entries in map02030
# map:map02030done!    295 / 563
# found 57 entries in map02040
# map:map02040done!    296 / 563
# found 115 entries in map04814
# map:map04814done!    297 / 563
# found 89 entries in map04810
# map:map04810done!    298 / 563
# found 138 entries in map04640
# map:map04640done!    299 / 563
# found 116 entries in map04610
# map:map04610done!    300 / 563
# found 93 entries in map04611
# map:map04611done!    301 / 563
# found 118 entries in map04613
# map:map04613done!    302 / 563
# found 95 entries in map04620
# map:map04620done!    303 / 563
# found 71 entries in map04624
# map:map04624done!    304 / 563
# found 189 entries in map04621
# map:map04621done!    305 / 563
# found 61 entries in map04622
# map:map04622done!    306 / 563
# found 56 entries in map04623
# map:map04623done!    307 / 563
# found 176 entries in map04625
# map:map04625done!    308 / 563
# found 118 entries in map04650
# map:map04650done!    309 / 563
# found 46 entries in map04612
# map:map04612done!    310 / 563
# found 82 entries in map04660
# map:map04660done!    311 / 563
# found 78 entries in map04658
# map:map04658done!    312 / 563
# found 109 entries in map04659
# map:map04659done!    313 / 563
# found 96 entries in map04657
# map:map04657done!    314 / 563
# found 59 entries in map04662
# map:map04662done!    315 / 563
# found 57 entries in map04664
# map:map04664done!    316 / 563
# found 61 entries in map04666
# map:map04666done!    317 / 563
# found 87 entries in map04670
# map:map04670done!    318 / 563
# found 62 entries in map04672
# map:map04672done!    319 / 563
# found 70 entries in map04062
# map:map04062done!    320 / 563
# found 60 entries in map04911
# map:map04911done!    321 / 563
# found 73 entries in map04910
# map:map04910done!    322 / 563
# found 89 entries in map04922
# map:map04922done!    323 / 563
# found 71 entries in map04923
# map:map04923done!    324 / 563
# found 46 entries in map04920
# map:map04920done!    325 / 563
# found 66 entries in map03320
# map:map03320done!    326 / 563
# found 55 entries in map04929
# map:map04929done!    327 / 563
# found 54 entries in map04912
# map:map04912done!    328 / 563
# found 77 entries in map04913
# map:map04913done!    329 / 563
# found 83 entries in map04915
# map:map04915done!    330 / 563
# found 44 entries in map04914
# map:map04914done!    331 / 563
# found 75 entries in map04917
# map:map04917done!    332 / 563
# found 82 entries in map04921
# map:map04921done!    333 / 563
# found 99 entries in map04926
# map:map04926done!    334 / 563
# found 71 entries in map04935
# map:map04935done!    335 / 563
# found 103 entries in map04918
# map:map04918done!    336 / 563
# found 113 entries in map04919
# map:map04919done!    337 / 563
# found 90 entries in map04928
# map:map04928done!    338 / 563
# found 49 entries in map04916
# map:map04916done!    339 / 563
# found 62 entries in map04924
# map:map04924done!    340 / 563
# found 45 entries in map04614
# map:map04614done!    341 / 563
# found 77 entries in map04925
# map:map04925done!    342 / 563
# found 65 entries in map04927
# map:map04927done!    343 / 563
# found 45 entries in map04260
# map:map04260done!    344 / 563
# found 79 entries in map04261
# map:map04261done!    345 / 563
# found 73 entries in map04270
# map:map04270done!    346 / 563
# found 75 entries in map04970
# map:map04970done!    347 / 563
# found 57 entries in map04971
# map:map04971done!    348 / 563
# found 98 entries in map04972
# map:map04972done!    349 / 563
# found 150 entries in map04976
# map:map04976done!    350 / 563
# found 69 entries in map04973
# map:map04973done!    351 / 563
# found 81 entries in map04974
# map:map04974done!    352 / 563
# found 72 entries in map04975
# map:map04975done!    353 / 563
# found 128 entries in map04979
# map:map04979done!    354 / 563
# found 113 entries in map04977
# map:map04977done!    355 / 563
# found 91 entries in map04978
# map:map04978done!    356 / 563
# found 31 entries in map04962
# map:map04962done!    357 / 563
# found 33 entries in map04960
# map:map04960done!    358 / 563
# found 60 entries in map04961
# map:map04961done!    359 / 563
# found 52 entries in map04964
# map:map04964done!    360 / 563
# found 24 entries in map04966
# map:map04966done!    361 / 563
# found 78 entries in map04724
# map:map04724done!    362 / 563
# found 62 entries in map04727
# map:map04727done!    363 / 563
# found 67 entries in map04725
# map:map04725done!    364 / 563
# found 76 entries in map04728
# map:map04728done!    365 / 563
# found 84 entries in map04726
# map:map04726done!    366 / 563
# found 36 entries in map04720
# map:map04720done!    367 / 563
# found 50 entries in map04730
# map:map04730done!    368 / 563
# found 92 entries in map04723
# map:map04723done!    369 / 563
# found 42 entries in map04721
# map:map04721done!    370 / 563
# found 88 entries in map04722
# map:map04722done!    371 / 563
# found 50 entries in map04744
# map:map04744done!    372 / 563
# found 47 entries in map04745
# map:map04745done!    373 / 563
# found 47 entries in map04740
# map:map04740done!    374 / 563
# found 71 entries in map04742
# map:map04742done!    375 / 563
# found 94 entries in map04750
# map:map04750done!    376 / 563
# found 28 entries in map04320
# map:map04320done!    377 / 563
# found 153 entries in map04360
# map:map04360done!    378 / 563
# found 75 entries in map04361
# map:map04361done!    379 / 563
# found 83 entries in map04380
# map:map04380done!    380 / 563
# found 62 entries in map04211
# map:map04211done!    381 / 563
# found 76 entries in map04212
# map:map04212done!    382 / 563
# found 72 entries in map04213
# map:map04213done!    383 / 563
# found 44 entries in map04710
# map:map04710done!    384 / 563
# found 63 entries in map04713
# map:map04713done!    385 / 563
# found 21 entries in map04711
# map:map04711done!    386 / 563
# found 36 entries in map04712
# map:map04712done!    387 / 563
# found 92 entries in map04714
# map:map04714done!    388 / 563
# found 88 entries in map04626
# map:map04626done!    389 / 563
# found 331 entries in map05200
# map:map05200done!    390 / 563
# found 215 entries in map05202
# map:map05202done!    391 / 563
# found 460 entries in map05206
# map:map05206done!    392 / 563
# found 214 entries in map05205
# map:map05205done!    393 / 563
# found 152 entries in map05204
# map:map05204done!    394 / 563
# found 193 entries in map05207
# map:map05207done!    395 / 563
# found 233 entries in map05208
# map:map05208done!    396 / 563
# found 240 entries in map05203
# map:map05203done!    397 / 563
# found 131 entries in map05230
# map:map05230done!    398 / 563
# found 60 entries in map05231
# map:map05231done!    399 / 563
# found 90 entries in map05235
# map:map05235done!    400 / 563
# found 84 entries in map05210
# map:map05210done!    401 / 563
# found 65 entries in map05212
# map:map05212done!    402 / 563
# found 122 entries in map05225
# map:map05225done!    403 / 563
# found 104 entries in map05226
# map:map05226done!    404 / 563
# found 84 entries in map05214
# map:map05214done!    405 / 563
# found 32 entries in map05216
# map:map05216done!    406 / 563
# found 57 entries in map05221
# map:map05221done!    407 / 563
# found 60 entries in map05220
# map:map05220done!    408 / 563
# found 32 entries in map05217
# map:map05217done!    409 / 563
# found 40 entries in map05218
# map:map05218done!    410 / 563
# found 68 entries in map05211
# map:map05211done!    411 / 563
# found 39 entries in map05219
# map:map05219done!    412 / 563
# found 69 entries in map05215
# map:map05215done!    413 / 563
# found 55 entries in map05213
# map:map05213done!    414 / 563
# found 125 entries in map05224
# map:map05224done!    415 / 563
# found 55 entries in map05222
# map:map05222done!    416 / 563
# found 66 entries in map05223
# map:map05223done!    417 / 563
# found 166 entries in map05166
# map:map05166done!    418 / 563
# found 173 entries in map05170
# map:map05170done!    419 / 563
# found 171 entries in map05161
# map:map05161done!    420 / 563
# found 129 entries in map05160
# map:map05160done!    421 / 563
# found 205 entries in map05171
# map:map05171done!    422 / 563
# found 166 entries in map05164
# map:map05164done!    423 / 563
# found 139 entries in map05162
# map:map05162done!    424 / 563
# found 174 entries in map05168
# map:map05168done!    425 / 563
# found 201 entries in map05163
# map:map05163done!    426 / 563
# found 173 entries in map05167
# map:map05167done!    427 / 563
# found 177 entries in map05169
# map:map05169done!    428 / 563
# found 180 entries in map05165
# map:map05165done!    429 / 563
# found 55 entries in map05110
# map:map05110done!    430 / 563
# found 62 entries in map05120
# map:map05120done!    431 / 563
# found 193 entries in map05130
# map:map05130done!    432 / 563
# found 236 entries in map05132
# map:map05132done!    433 / 563
# found 251 entries in map05131
# map:map05131done!    434 / 563
# found 130 entries in map05135
# map:map05135done!    435 / 563
# found 98 entries in map05133
# map:map05133done!    436 / 563
# found 75 entries in map05134
# map:map05134done!    437 / 563
# found 72 entries in map05150
# map:map05150done!    438 / 563
# found 142 entries in map05152
# map:map05152done!    439 / 563
# found 73 entries in map05100
# map:map05100done!    440 / 563
# found 88 entries in map05146
# map:map05146done!    441 / 563
# found 65 entries in map05144
# map:map05144done!    442 / 563
# found 82 entries in map05145
# map:map05145done!    443 / 563
# found 65 entries in map05140
# map:map05140done!    444 / 563
# found 87 entries in map05142
# map:map05142done!    445 / 563
# found 53 entries in map05143
# map:map05143done!    446 / 563
# found 46 entries in map05310
# map:map05310done!    447 / 563
# found 62 entries in map05322
# map:map05322done!    448 / 563
# found 60 entries in map05323
# map:map05323done!    449 / 563
# found 55 entries in map05320
# map:map05320done!    450 / 563
# found 74 entries in map05321
# map:map05321done!    451 / 563
# found 43 entries in map05330
# map:map05330done!    452 / 563
# found 34 entries in map05332
# map:map05332done!    453 / 563
# found 52 entries in map05340
# map:map05340done!    454 / 563
# found 166 entries in map05010
# map:map05010done!    455 / 563
# found 150 entries in map05012
# map:map05012done!    456 / 563
# found 173 entries in map05014
# map:map05014done!    457 / 563
# found 122 entries in map05016
# map:map05016done!    458 / 563
# found 115 entries in map05017
# map:map05017done!    459 / 563
# found 122 entries in map05020
# map:map05020done!    460 / 563
# found 306 entries in map05022
# map:map05022done!    461 / 563
# found 83 entries in map05030
# map:map05030done!    462 / 563
# found 107 entries in map05031
# map:map05031done!    463 / 563
# found 106 entries in map05032
# map:map05032done!    464 / 563
# found 71 entries in map05033
# map:map05033done!    465 / 563
# found 102 entries in map05034
# map:map05034done!    466 / 563
# found 221 entries in map05417
# map:map05417done!    467 / 563
# found 109 entries in map05418
# map:map05418done!    468 / 563
# found 53 entries in map05410
# map:map05410done!    469 / 563
# found 69 entries in map05412
# map:map05412done!    470 / 563
# found 53 entries in map05414
# map:map05414done!    471 / 563
# found 162 entries in map05415
# map:map05415done!    472 / 563
# found 45 entries in map05416
# map:map05416done!    473 / 563
# found 38 entries in map04930
# map:map04930done!    474 / 563
# found 27 entries in map04940
# map:map04940done!    475 / 563
# found 38 entries in map04950
# map:map04950done!    476 / 563
# found 143 entries in map04936
# map:map04936done!    477 / 563
# found 81 entries in map04932
# map:map04932done!    478 / 563
# found 151 entries in map04931
# map:map04931done!    479 / 563
# found 77 entries in map04933
# map:map04933done!    480 / 563
# found 0 entries in map04934
# map:map04934done!    481 / 563
# found 0 entries in map01501
# map:map01501done!    482 / 563
# found 0 entries in map01502
# map:map01502done!    483 / 563
# found 0 entries in map01503
# map:map01503done!    484 / 563
# found 0 entries in map01521
# map:map01521done!    485 / 563
# found 0 entries in map01524
# map:map01524done!    486 / 563
# found 0 entries in map01523
# map:map01523done!    487 / 563
# found 0 entries in map01522
# map:map01522done!    488 / 563
# found 0 entries in map07011
# map:map07011done!    489 / 563
# found 0 entries in map07012
# map:map07012done!    490 / 563
# found 0 entries in map07013
# map:map07013done!    491 / 563
# found 0 entries in map07021
# map:map07021done!    492 / 563
# found 0 entries in map07019
# map:map07019done!    493 / 563
# found 0 entries in map07020
# map:map07020done!    494 / 563
# found 0 entries in map07014
# map:map07014done!    495 / 563
# found 0 entries in map07023
# map:map07023done!    496 / 563
# found 0 entries in map07026
# map:map07026done!    497 / 563
# found 0 entries in map07044
# map:map07044done!    498 / 563
# found 0 entries in map07053
# map:map07053done!    499 / 563
# found 0 entries in map07040
# map:map07040done!    500 / 563
# found 0 entries in map07041
# map:map07041done!    501 / 563
# found 0 entries in map07042
# map:map07042done!    502 / 563
# found 0 entries in map07043
# map:map07043done!    503 / 563
# found 0 entries in map07045
# map:map07045done!    504 / 563
# found 0 entries in map07032
# map:map07032done!    505 / 563
# found 0 entries in map07030
# map:map07030done!    506 / 563
# found 0 entries in map07033
# map:map07033done!    507 / 563
# found 0 entries in map07015
# map:map07015done!    508 / 563
# found 0 entries in map07039
# map:map07039done!    509 / 563
# found 0 entries in map07028
# map:map07028done!    510 / 563
# found 0 entries in map07029
# map:map07029done!    511 / 563
# found 0 entries in map07031
# map:map07031done!    512 / 563
# found 0 entries in map07027
# map:map07027done!    513 / 563
# found 0 entries in map07056
# map:map07056done!    514 / 563
# found 0 entries in map07057
# map:map07057done!    515 / 563
# found 0 entries in map07055
# map:map07055done!    516 / 563
# found 0 entries in map07016
# map:map07016done!    517 / 563
# found 0 entries in map07017
# map:map07017done!    518 / 563
# found 0 entries in map07018
# map:map07018done!    519 / 563
# found 0 entries in map07037
# map:map07037done!    520 / 563
# found 0 entries in map07038
# map:map07038done!    521 / 563
# found 0 entries in map07046
# map:map07046done!    522 / 563
# found 0 entries in map07047
# map:map07047done!    523 / 563
# found 0 entries in map07048
# map:map07048done!    524 / 563
# found 0 entries in map07049
# map:map07049done!    525 / 563
# found 0 entries in map07050
# map:map07050done!    526 / 563
# found 0 entries in map07051
# map:map07051done!    527 / 563
# found 0 entries in map07052
# map:map07052done!    528 / 563
# found 0 entries in map07054
# map:map07054done!    529 / 563
# found 0 entries in map07220
# map:map07220done!    530 / 563
# found 0 entries in map07215
# map:map07215done!    531 / 563
# found 0 entries in map07214
# map:map07214done!    532 / 563
# found 0 entries in map07213
# map:map07213done!    533 / 563
# found 0 entries in map07212
# map:map07212done!    534 / 563
# found 0 entries in map07227
# map:map07227done!    535 / 563
# found 0 entries in map07211
# map:map07211done!    536 / 563
# found 0 entries in map07228
# map:map07228done!    537 / 563
# found 0 entries in map07224
# map:map07224done!    538 / 563
# found 0 entries in map07229
# map:map07229done!    539 / 563
# found 0 entries in map07225
# map:map07225done!    540 / 563
# found 0 entries in map07226
# map:map07226done!    541 / 563
# found 0 entries in map07223
# map:map07223done!    542 / 563
# found 0 entries in map07222
# map:map07222done!    543 / 563
# found 0 entries in map07221
# map:map07221done!    544 / 563
# found 0 entries in map07230
# map:map07230done!    545 / 563
# found 0 entries in map07036
# map:map07036done!    546 / 563
# found 0 entries in map07231
# map:map07231done!    547 / 563
# found 0 entries in map07232
# map:map07232done!    548 / 563
# found 0 entries in map07235
# map:map07235done!    549 / 563
# found 0 entries in map07233
# map:map07233done!    550 / 563
# found 33 entries in map07234
# map:map07234done!    551 / 563
# found 29 entries in map07216
# map:map07216done!    552 / 563
# found 41 entries in map07219
# map:map07219done!    553 / 563
# found 11 entries in map07024
# map:map07024done!    554 / 563
# found 21 entries in map07217
# map:map07217done!    555 / 563
# found 18 entries in map07218
# map:map07218done!    556 / 563
# found 13 entries in map07025
# map:map07025done!    557 / 563
# found 21 entries in map07034
# map:map07034done!    558 / 563
# found 21 entries in map07035
# map:map07035done!    559 / 563
# found 26 entries in map07110
# map:map07110done!    560 / 563
# found 9 entries in map07112
# map:map07112done!    561 / 563
# found 21 entries in map07114
# map:map07114done!    562 / 563
# found 19 entries in map07117
# map:map07117done!    563 / 563

# %% [markdown]
# ## Read R entries

# %%
import pandas as pd
import re

KEGG_pathways_reactions = pd.DataFrame(columns=['pw_ID','pw_name','coords','href','title','R_ID'])
KEGG_pathways_entrys = pd.read_csv('KEGG\\KEGG_pathways_entrys.txt', sep='\t',dtype={'pw_ID':str,'pw_name':str,'href':str,'title':str}).drop_duplicates()
for index, row in KEGG_pathways_entrys.iterrows():
    rs = re.findall(r'R\d{5}',row['title'])
    if rs:
        for r in rs:
            KEGG_pathways_reactions.loc[len(KEGG_pathways_reactions.index)]=[row['pw_ID'],row['pw_name'],row['coords'],row['href'],row['title'],r]
     
KEGG_pathways_reactions.drop_duplicates().reset_index().to_csv('KEGG\\KEGG_pathways_reactions.txt',sep='\t',index=False)

# %% [markdown]
# ## Read KO entries

# %%
import pandas as pd
import re

KEGG_pathways_kos = pd.DataFrame(columns=['pw_ID','pw_name','coords','href','title','KO_ID'])
KEGG_pathways_entrys = pd.read_csv('KEGG\\KEGG_pathways_entrys.txt', sep='\t',dtype={'pw_ID':str,'pw_name':str,'href':str,'title':str}).drop_duplicates()
for index, row in KEGG_pathways_entrys.iterrows():
    kos = re.findall(r'K\d{5}',row['title'])
    if kos:
        for ko in kos:
            KEGG_pathways_kos.loc[len(KEGG_pathways_kos.index)]=[row['pw_ID'],row['pw_name'],row['coords'],row['href'],row['title'],ko]
     
KEGG_pathways_kos.drop_duplicates().reset_index().to_csv('KEGG\\KEGG_pathways_kos.txt',sep='\t',index=False)

# %% [markdown]
# ## Download map picture

# %%
import pandas as pd
import requests
import json

with open('KEGG\\KEGG_pathways_name.json', 'r') as f:
    pathways_name_dir = json.load(f)
f.close()

pathways_list = [i for i in pathways_name_dir.keys()]

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'}

m = 1
for pathway in pathways_list:
    downloadurl = 'https://www.kegg.jp/kegg/pathway/map/'+pathway+'@2x.png'
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'}
    pict=requests.get(downloadurl,headers = headers).content
    with open('KEGG\\maps\\maps\\'+pathway+'.png','wb') as f:
        f.write(pict)
    print(pathway+' done!    '+str(m)+' / '+str(len(pathways_list)))
    m=m+1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\lix\Documents\GitHub\BuildGEM\1_KEGG_download.ipynb 单元格 12 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/lix/Documents/GitHub/BuildGEM/1_KEGG_download.ipynb#X12sZmlsZQ%3D%3D?line=14'>15</a> downloadurl = 'https://www.kegg.jp/kegg/pathway/map/'+pathway+'@2x.png'
#      <a href='vscode-notebook-cell:/c%3A/Users/lix/Documents/GitHub/BuildGEM/1_KEGG_download.ipynb#X12sZmlsZQ%3D%3D?line=15'>16</a> headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'}
# ---> <a href='vscode-notebook-cell:/c%3A/Users/lix/Documents/GitHub/BuildGEM/1_KEGG_download.ipynb#X12sZmlsZQ%3D%3D?line=16'>17</a> pict=requests.get(downloadurl,headers = headers).content
#      <a href='vscode-notebook-cell:/c%3A/Users/lix/Documents/GitHub/BuildGEM/1_KEGG_download.ipynb#X12sZmlsZQ%3D%3D?line=17'>18</a> with open('KEGG\\maps\\maps\\'+pathway+'.png','wb') as f:
#      <a href='vscode-notebook-cell:/c%3A/Users/lix/Documents/GitHub/BuildGEM/1_KEGG_download.ipynb#X12sZmlsZQ%3D%3D?line=18'>19</a>     f.write(pict)
#
# File c:\Users\lix\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\lix\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\lix\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\lix\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File c:\Users\lix\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File c:\Users\lix\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File c:\Users\lix\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py:937, in HTTPResponse.stream(self, amt, decode_content)
#     921 """
#     922 A generator wrapper for the read() method. A call will block until
#     923 ``amt`` bytes have been read from the connection or until the
#    (...)
#     934     'content-encoding' header.
#     935 """
#     936 if self.chunked and self.supports_chunked_reads():
# --> 937     yield from self.read_chunked(amt, decode_content=decode_content)
#     938 else:
#     939     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File c:\Users\lix\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py:1080, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1078 if self.chunk_left == 0:
#    1079     break
# -> 1080 chunk = self._handle_chunk(amt)
#    1081 decoded = self._decode(
#    1082     chunk, decode_content=decode_content, flush_decoder=False
#    1083 )
#    1084 if decoded:
#
# File c:\Users\lix\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py:1022, in HTTPResponse._handle_chunk(self, amt)
#    1020     self.chunk_left = None
#    1021 elif self.chunk_left is not None and amt < self.chunk_left:
# -> 1022     value = self._fp._safe_read(amt)  # type: ignore[union-attr]
#    1023     self.chunk_left = self.chunk_left - amt
#    1024     returned_chunk = value
#
# File c:\Users\lix\AppData\Local\Programs\Python\Python39\lib\http\client.py:626, in HTTPResponse._safe_read(self, amt)
#     624 s = []
#     625 while amt > 0:
# --> 626     chunk = self.fp.read(min(amt, MAXAMOUNT))
#     627     if not chunk:
#     628         raise IncompleteRead(b''.join(s), amt)
#
# File c:\Users\lix\AppData\Local\Programs\Python\Python39\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File c:\Users\lix\AppData\Local\Programs\Python\Python39\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\lix\AppData\Local\Programs\Python\Python39\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## show reaction on map picture

# %%
import myModules.KEGG2BIGG as K2B
unikegglist = list(set(K2B.KEGG_pathways_reactions['R_ID'].tolist()))
a = K2B.pd.read_csv('KEGG\\Reaction_in_pathway_count.csv',index_col=0,squeeze=True)
# Out:
# C:\Users\lix\AppData\Local\Temp\ipykernel_12860\3646173753.py:3: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   a = K2B.pd.read_csv('KEGG\\Reaction_in_pathway_count.csv',index_col=0,squeeze=True)

# %%
from PIL import Image, ImageFont, ImageDraw

def drawtext(draw,text,coords_list):
    box = draw.textbbox((0,0),text, font=font)
    w = box[2] - box[0]
    h = box[3] - box[1]
    if type(coords_list) == list:
        coords_num = [2*int(i) for i in coords_list]
        x = (coords_num[0]+coords_num[2])/2
        y = (coords_num[1]+coords_num[3])/2
        draw.rectangle(coords_num, fill=(237, 245, 249), outline=(0,0,0),width=1)
        draw.text((x-w/2,y-h/2), text, font=font,fill=(0,0,0))
    else:
        print('coords_list should be a list')

map_list=[key for key in a.keys()]
#map_list = ['map00030']
font = ImageFont.truetype("arial.ttf", 18)
for mapp in map_list:
    map_reactions = K2B.KEGG_pathways_reactions[K2B.KEGG_pathways_reactions['pw_ID']==mapp]
    img = Image.open("KEGG\\maps\\maps\\%s.png"%mapp)
    draw = ImageDraw.Draw(img)
    for r in map_reactions['R_ID']:
        text = r
        findresult = map_reactions[map_reactions['R_ID']==r]['coords'].to_list()
        for i in findresult:
            coords_list = i.split(',')
            if len(coords_list) == 4:
                drawtext(draw,text,coords_list)
    img.save('KEGG\\maps\\mapasR\\%s_asR.png'%mapp)

# %% [markdown]
# # Download KEGG reaction/compound database

# %%
# download KEGG reactions
import requests
from lxml import etree
import re
import time
import pandas as pd

KEGG_REACTIONS_list = requests.get('https://rest.kegg.jp/list/reaction')
f = open("KEGG\\KEGG_REACTIONS_list.txt", 'w')
f.write(KEGG_REACTIONS_list.text)

kegg_rxn_list = pd.read_table('KEGG\\KEGG_REACTIONS_list.txt',header=None)
kegg_rlist = [st.replace('rn:','') for st in kegg_rxn_list[0]]

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'}
f = open("KEGG\\KEGG_REACTIONS_DB.txt", 'a')
f.write('ID\tNAMES\tKEGG\tEQUATION\tECs\n')

for id in kegg_rlist:
    url ='https://www.kegg.jp/entry/'+id
    try:
        html = requests.get(url,headers = headers)
    except requests.exceptions.Timeout:
        print("time out, try again")
        time.sleep(20)
        html = requests.get(url,headers = headers)
    if not html.ok:
        print('wrong reaction ID')
        time.sleep(20)
        html = requests.get(url,headers = headers)
        if not html.ok:
            continue

    e = etree.HTML(html.text)

    name_content = e.xpath('//th/span[text()="Name"]/../../td/div/div/text()')
    name = ''
    for st in name_content[:-1]:
        name = name +st.replace('\n','').replace(';','|')
    
    equation_content = e.xpath('//th/span[text()="Equation"]/../../td/div//text()')
    equation = ''
    for st in equation_content[:-1]:
        if st.startswith('C'):
            st = st+'[0]'
        else:
            matches = re.compile(r"\d+").findall(st)
            if matches:
                match = matches[0]
                st = st.replace(match, f"({match})")    
        equation = equation + st
    
    EC_content = e.xpath('//th/span[text()="Enzyme"]/../../td/div//text()')
    EC1 = [i.replace(u'\xa0','\n') for i in EC_content]
    EC2 = [i for i in EC1 if not str(i).startswith('\n')]
    EC = ''
    for st in EC2:
        EC = EC + st + '|'
    EC = EC[:-1]
    f.write(id+'\t'+name+'\t'+id+'\t'+equation+'\t'+EC+'\n')
f.close()

# %%
# KEGG reaction to ModelSEED reaction
import modelseedpy

modelseed_path = 'C:\\Users\\vickenlee\\ModelSEEDDatabase'
modelseed = modelseedpy.biochem.from_local(modelseed_path)

df_keggID_modelseedID = pd.DataFrame(columns=["Kegg_ID","ModelSeed_ID"])
for (key,value) in modelseed.reaction_aliases.items():
    ModelSeed_ID = key
    try:    
        Kegg_ID = list(value.get('KEGG'))[0]
    except:
            Kegg_ID =''
    df_keggID_modelseedID.loc[len(df_keggID_modelseedID.index)]=[Kegg_ID,ModelSeed_ID]
df_keggID_modelseedID.to_csv('KEGG\\KEGG_reaction_keggID_modelseedID.txt',  header=True, index=False,sep='\t')

print('done!')

# %%
# download KEGG compounds and map to ModelSEED compounds

KEGG_COMPOUNDS_list = requests.get('https://rest.kegg.jp/list/compound')
f = open("KEGG\\KEGG_COMPOUNDS_list.txt", 'w')
f.write(KEGG_COMPOUNDS_list.text)
kegg_cpd_list = pd.read_table('KEGG\\KEGG_COMPOUNDS_list.txt',header=None)
KEGG_COMPOUNDS_name = pd.DataFrame(columns=['ID','Name'])
KEGG_COMPOUNDS_name['ID']=[st.replace('cpd:','') for st in kegg_cpd_list[0]]
KEGG_COMPOUNDS_name['Name']=[st.replace('; ','|') for st in kegg_cpd_list[1]]


import modelseedpy
modelseed_path = 'C:\\Users\\vickenlee\\ModelSEEDDatabase'
modelseed = modelseedpy.biochem.from_local(modelseed_path)
cpd_keggID_modelseedID = pd.DataFrame(columns=["Kegg_ID","ModelSeed_ID","formula","charge"])
for (key,value) in modelseed.compound_aliases.items():
    ModelSeed_ID = key
    compound = modelseed.get_seed_compound(ModelSeed_ID)
    formula = compound.formula
    charge = compound.data['charge']
    try:    
        find_Kegg = list(value.get('KEGG'))
    except:
            find_Kegg =''
    if find_Kegg:
        for Kegg_ID in find_Kegg:
            cpd_keggID_modelseedID.loc[len(cpd_keggID_modelseedID.index)]=[Kegg_ID,ModelSeed_ID,formula,charge]
cpd_keggID_modelseedID.to_csv('KEGG\\KEGG_compound_keggID_modelseedID.txt', header=True,sep='\t',index=False)
cpd_keggID_modelseedID=cpd_keggID_modelseedID.rename(columns={'Kegg_ID':'ID'})


KEGG_COMPOUNDS_DB = pd.merge(KEGG_COMPOUNDS_name,cpd_keggID_modelseedID,how='left',on='ID').drop_duplicates(subset=['ID'], keep='first')


from lxml import etree
for index, row in KEGG_COMPOUNDS_DB.iterrows():
    if not row['formula']==row['formula']:
        url ='https://www.kegg.jp/entry/'+row['ID']
        try:
            html = requests.get(url,headers = headers)
        except requests.exceptions.Timeout:
            time.sleep(20)
            html = requests.get(url,headers = headers)
        e = etree.HTML(html.text)
        formula_content = e.xpath('//th/span[text()="Formula"]/../../td/div/text()')
        if formula_content:
            formula = formula_content[0]
            KEGG_COMPOUNDS_DB['formula'][index]=formula
            print(row['ID']+': add formula')
        else:
            print(row['ID']+': does not have formula')

KEGG_COMPOUNDS_DB.to_csv('Database\\KEGG_COMPOUNDS_DB.txt',sep='\t',index=None)

# %% [markdown]
# # Download species KEGG

# %%
org_name = 'mko'
org_full_name = 'Methylomonas_koyamae'

# %%
org_name = 'mbry'
org_full_name = 'Methylocystis_bryophila'

# %%
org_name = 'mca'
org_full_name = 'Methylococcus_capsulatus'

# %%
import myModules.KEGGdownload as kd

# %%
pwlist = kd.getpwlist(org_name)

# %%
kd.downloadxml(org_name,pwlist)

# %%
df_reaction = kd.getentriesfromxml(org_name)

# %% [markdown]
# # Get KEGG reaction from genome

# %%
org_name = 'mko'
org_full_name = 'Methylomonas_koyamae'

# %%
org_name = 'mbry'
org_full_name = 'Methylocystis_bryophila'

# %%
org_name = 'mca'
org_full_name = 'Methylococcus_capsulatus'

# %%
import os
faa_paths=[]
for root, dirs, files in os.walk('genome\\'+org_full_name+'_genome'):
    if 'protein.faa' in files:
        genome_path = root+'\\protein.faa'
print(genome_path)
# Out:
# genome\Methylocystis_bryophila_genome\ncbi_dataset\data\GCA_027925445.1\protein.faa

# %% [markdown]
# 1. upload protein.faa to https://www.kegg.jp/blastkoala/
#
# 2. download the blast result to genome\\XXX_genome\\user_ko.txt

# %%
import myModules.KEGG2BIGG as K2B
import pandas as pd

df_org_ko = pd.read_csv('genome\\'+org_full_name+'_genome\\user_ko.txt',sep='\t',header=None)
df_org_ko.columns = ['Genes','KO_ID']
ko_list = df_org_ko['KO_ID'].tolist()
R_list =[]
for ko in ko_list:
    try:
        R = K2B.getRfromKO(ko)
        if type(R) == list:
            R_list+=R
        elif type(R) == str:
# map00010 25 Glycolysis / Gluconeogenesis
# map00970 25 Aminoacyl-tRNA biosynthesis
# map02025 24 Biofilm formation - Pseudomonas aeruginosa
# map00920 24 Sulfur metabolism
# map03440 22 Homologous recombination
# map00910 22 Nitrogen metabolism
# map00260 22 Glycine, serine and threonine metabolism
# map00030 21 Pentose phosphate pathway
# map02026 20 Biofilm formation - Escherichia coli
# map00020 20 Citrate cycle (TCA cycle)
# map00541 19 O-Antigen nucleotide sugar biosynthesis
# map00550 19 Peptidoglycan biosynthesis
# map00540 19 Lipopolysaccharide biosynthesis
# map00250 19 Alanine, aspartate and glutamate metabolism
# map00400 18 Phenylalanine, tyrosine and tryptophan biosynthesis
# map03430 17 Mismatch repair
# map00220 16 Arginine biosynthesis
# map03018 16 RNA degradation
# map00500 16 Starch and sucrose metabolism
# map00330 16 Arginine and proline metabolism
# map02030 16 Bacterial chemotaxis
# map03060 16 Protein export
# map04122 15 Sulfur relay system
# map00760 15 Nicotinate and nicotinamide metabolism
# map00770 15 Pantothenate and CoA biosynthesis
# map03030 14 DNA replication
# map00061 13 Fatty acid biosynthesis
# map04112 13 Cell cycle - Caulobacter
# map00300 13 Lysine biosynthesis
# map00340 12 Histidine metabolism
# map00564 12 Glycerophospholipid metabolism
# map00640 12 Propanoate metabolism
# map00290 11 Valine, leucine and isoleucine biosynthesis
# map00710 11 Carbon fixation in photosynthetic organisms
# map00480 11 Glutathione metabolism
# map00730 11 Thiamine metabolism
# map00900 11 Terpenoid backbone biosynthesis
# map00670 11 One carbon pool by folate
# map00780 11 Biotin metabolism
# map00785 11 Lipoic acid metabolism
# map00650 10 Butanoate metabolism
# map00561 10 Glycerolipid metabolism
# map03410 10 Base excision repair
# map00740 9 Riboflavin metabolism
# map00660 9 C5-Branched dibasic acid metabolism
# map00983 9 Drug metabolism - other enzymes
# map00051 9 Fructose and mannose metabolism
# map00130 9 Ubiquinone and other terpenoid-quinone biosynthesis
# map00543 8 Exopolysaccharide biosynthesis
# map04714 8 Thermogenesis
# map00195 8 Photosynthesis
# map00521 8 Streptomycin biosynthesis
# map00261 8 Monobactam biosynthesis
# map00470 7 D-Amino acid metabolism
# map03420 7 Nucleotide excision repair
# map00360 7 Phenylalanine metabolism
# map00450 7 Selenocompound metabolism
# map00350 6 Tyrosine metabolism
# map04626 6 Plant-pathogen interaction
# map00625 6 Chloroalkane and chloroalkene degradation
# map05415 6 Diabetic cardiomyopathy
# map05208 5 Chemical carcinogenesis - reactive oxygen species
# map05012 5 Parkinson disease
# map05016 5 Huntington disease
# map00052 5 Galactose metabolism
# map00380 5 Tryptophan metabolism
# map00791 5 Atrazine degradation
# map04212 5 Longevity regulating pathway - worm
# map05132 4 Salmonella infection
# map05418 4 Fluid shear stress and atherosclerosis
# map00430 4 Taurine and hypotaurine metabolism
# map00280 4 Valine, leucine and isoleucine degradation
# map04146 4 Peroxisome
# map05134 4 Legionellosis
# map00750 4 Vitamin B6 metabolism
# map00310 4 Lysine degradation
# map00040 4 Pentose and glucuronate interconversions
# map05133 4 Pertussis
# map05022 4 Pathways of neurodegeneration - multiple diseases
# map00523 4 Polyketide sugar unit biosynthesis
# map05014 4 Amyotrophic lateral sclerosis
# map05010 4 Alzheimer disease
# map04260 4 Cardiac muscle contraction
# map03020 4 RNA polymerase
# map04213 3 Longevity regulating pathway - multiple species
# map04070 3 Phosphatidylinositol signaling system
# map00405 3 Phenazine biosynthesis
# map04978 3 Mineral absorption
# map00562 3 Inositol phosphate metabolism
# map05230 3 Central carbon metabolism in cancer
# map04217 3 Necroptosis
# map04621 3 NOD-like receptor signaling pathway
# map04922 3 Glucagon signaling pathway
# map00906 3 Carotenoid biosynthesis
# map00999 3 Biosynthesis of various plant secondary metabolites
# map00982 3 Drug metabolism - cytochrome P450
# map00460 3 Cyanoamino acid metabolism
# map05417 3 Lipid and atherosclerosis
# map00053 3 Ascorbate and aldarate metabolism
# map00627 3 Aminobenzoate degradation
# map05020 3 Prion disease
# map00071 3 Fatty acid degradation
# map04066 3 HIF-1 signaling pathway
# map05152 3 Tuberculosis
# map04931 3 Insulin resistance
# map04932 3 Non-alcoholic fatty liver disease
# map00401 3 Novobiocin biosynthesis
# map00633 2 Nitrotoluene degradation
# map04141 2 Protein processing in endoplasmic reticulum
# map00966 2 Glucosinolate biosynthesis
# map05200 2 Pathways in cancer
# map05207 2 Chemical carcinogenesis - receptor activation
# map00311 2 Penicillin and cephalosporin biosynthesis
# map04016 2 MAPK signaling pathway - plant
# map04918 2 Thyroid hormone synthesis
# map00332 2 Carbapenem biosynthesis
# map04910 2 Insulin signaling pathway
# map00552 2 Teichoic acid biosynthesis
# map00333 2 Prodigiosin biosynthesis
# map00525 2 Acarbose and validamycin biosynthesis
# map00950 2 Isoquinoline alkaloid biosynthesis
# map03008 2 Ribosome biogenesis in eukaryotes
# map00960 2 Tropane, piperidine and pyridine alkaloid biosynthesis
# map00410 2 beta-Alanine metabolism
# map00980 2 Metabolism of xenobiotics by cytochrome P450
# map00940 2 Phenylpropanoid biosynthesis
# map05120 2 Epithelial cell signaling in Helicobacter pylori infection
# map01220 2 Degradation of aromatic compounds
# map04960 1 Aldosterone-regulated sodium reabsorption
# map04973 1 Carbohydrate digestion and absorption
# map04974 1 Protein digestion and absorption
# map05215 1 Prostate cancer
# map04657 1 IL-17 signaling pathway
# map04961 1 Endocrine and other factor-regulated calcium reabsorption
# map04915 1 Estrogen signaling pathway
# map04964 1 Proximal tubule bicarbonate reclamation
# map01055 1 Biosynthesis of vancomycin group antibiotics
# map04151 1 PI3K-Akt signaling pathway
# map04612 1 Antigen processing and presentation
# map04914 1 Progesterone-mediated oocyte maturation
# map04659 1 Th17 cell differentiation
# map00830 1 Retinol metabolism
# map04072 1 Phospholipase D signaling pathway
# map04068 1 FoxO signaling pathway
# map04113 1 Meiosis - yeast
# map04214 1 Apoptosis - fly
# map00984 1 Steroid degradation
# map05205 1 Proteoglycans in cancer
# map05225 1 Hepatocellular carcinoma
# map05204 1 Chemical carcinogenesis - DNA adducts
# map00531 1 Glycosaminoglycan degradation
# map00908 1 Zeatin biosynthesis
# map04211 1 Longevity regulating pathway
# map04013 1 MAPK signaling pathway - fly
# map04361 1 Axon regeneration
# map05131 1 Shigellosis
# map05034 1 Alcoholism
# map05031 1 Amphetamine addiction
# map05030 1 Cocaine addiction
# map04726 1 Serotonergic synapse
# map04728 1 Dopaminergic synapse
# map04972 1 Pancreatic secretion
# map00514 1 Other types of O-glycan biosynthesis
# map05231 1 Choline metabolism in cancer
# map04976 1 Bile secretion
# map05340 1 Primary immunodeficiency
# map04971 1 Gastric acid secretion
# map00511 1 Other glycan degradation
# map04723 1 Retrograde endocannabinoid signaling
# map04923 1 Regulation of lipolysis in adipocytes
# map01040 1 Biosynthesis of unsaturated fatty acids
# map00998 1 Biosynthesis of various antibiotics
# map05110 1 Vibrio cholerae infection
# map04727 1 GABAergic synapse
# map04724 1 Glutamatergic synapse
# map00623 1 Toluene degradation
# map00361 1 Chlorocyclohexane and chlorobenzene degradation
# map00364 1 Fluorobenzoate degradation
# map04940 1 Type I diabetes mellitus
# map00930 1 Caprolactam degradation
# map03320 1 PPAR signaling pathway
# map04920 1 Adipocytokine signaling pathway
# map04216 1 Ferroptosis
# map00909 1 Sesquiterpenoid and triterpenoid biosynthesis
# map00626 1 Naphthalene degradation
# map00600 1 Sphingolipid metabolism
# map04142 1 Lysosome
# map04970 1 Salivary secretion
# map05130 1 Pathogenic Escherichia coli infection
# map04261 1 Adrenergic signaling in cardiomyocytes
# map04925 1 Aldosterone synthesis and secretion
# map04919 1 Thyroid hormone signaling pathway
# map04911 1 Insulin secretion
# map04022 1 cGMP-PKG signaling pathway
# map04024 1 cAMP signaling pathway
# map04210 1 Apoptosis
# map00946 1 Degradation of flavonoids
# map00362 1 Benzoate degradation
# map00643 1 Styrene degradation
# map00510 1 N-Glycan biosynthesis
# map04930 1 Type II diabetes mellitus
# map05165 1 Human papillomavirus infection
# map05203 1 Viral carcinogenesis
# map00524 1 Neomycin, kanamycin and gentamicin biosynthesis
# map04152 1 AMPK signaling pathway
# map01051 1 Biosynthesis of ansamycins
# map05100 1 Bacterial invasion of epithelial cells

# %%
from PIL import Image, ImageFont, ImageDraw

def drawtext(draw,coords_list):
    if type(coords_list) == list:
        coords_num = [2*int(i) for i in coords_list]
        draw.rectangle(coords_num, fill=None, outline=(252, 85, 49),width=5)
    else:
        print('coords_list should be a list')

map_list=[key for key in a.keys()]
#map_list = ['map00680']
font = ImageFont.truetype("arial.ttf", 18)
for mapp in map_list:
    map_kos = K2B.KEGG_pathways_kos[K2B.KEGG_pathways_kos['pw_ID']==mapp]
    try:
        img = Image.open("KEGG\\maps\\mapedinBIGGandR\\%s_biggandR.png"%mapp)
    except:
        continue
    draw = ImageDraw.Draw(img)
    for ko in ko_list:
        text = ko
        findresult = map_kos[map_kos['KO_ID']==ko]['coords'].to_list()
        for i in findresult:
            coords_list = i.split(',')
            if len(coords_list) == 4:
                drawtext(draw,coords_list)
    img.save('KEGG\\maps\\%s_maps\\%s_%s.png'%(org_name,mapp,org_name))
