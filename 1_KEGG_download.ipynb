# %% [markdown]
# # Download global KEGG pathway database

# %%
import os
if not os.path.exists('KEGG'):
    os.makedirs('KEGG')

# %% [markdown]
# ##  Download KEGG pathway id/names

# %%
import requests
from lxml import etree
import json

pathways_name_dir = {}

url = 'https://www.kegg.jp/kegg/pathway.html'
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'}
html = requests.get(url,headers = headers)
e = etree.HTML(html.text)
idlist = e.xpath('//div[@class="list"]//dt/text()')
print('%d pathways ID found.'%len(idlist))
namelist = e.xpath('//div[@class="list"]//dd/a[1]/text()')
print('%d pathways name found.'%len(namelist))
if len(idlist) == len(namelist):
    for i in range(len(idlist)):
        pathways_name_dir['map'+idlist[i].strip()] = namelist[i].strip()
else:
    print('Error!')

with open('KEGG\\KEGG_pathways_name.json', 'w') as f:
    f.write(json.dumps(pathways_name_dir))
f.close()

# %% [markdown]
# ## Download KO, EC, R entries in KEGG pathways

# %%
import pandas as pd
import requests
from lxml import etree
import json

with open('KEGG\\KEGG_pathways_name.json', 'r') as f:
    pathways_name_dir = json.load(f)
f.close()

pathways_list = [i for i in pathways_name_dir.keys()]

KEGG_pathways_entrys = pd.DataFrame(columns=['pw_ID','pw_name','coords','href','title'])

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'}
m = 1
for pathway in pathways_list:
    pathway_name = pathways_name_dir[pathway]
    KEGG_pathway = requests.get('https://www.kegg.jp/pathway/'+pathway,headers = headers)
    e = etree.HTML(KEGG_pathway.text)
    hreflist = e.xpath('//map[@id="mapdata"]/area/@href')
    coordslist = e.xpath('//map[@id="mapdata"]/area/@coords')
    entrylist = e.xpath('//map[@id="mapdata"]/area/@title')
    print('found %d entries in %s'%(len(hreflist),pathway))
    if not len(hreflist) == len(entrylist):
        print(pathway,'Error!')
        continue
    for i in range(len(hreflist)):
        href = hreflist[i]
        coords = coordslist[i]
        title = entrylist[i]
        KEGG_pathways_entrys.loc[len(KEGG_pathways_entrys.index)]=[pathway,pathway_name,coords,href,title]

    print('map:'+pathway+'done!    '+str(m)+' / '+str(len(pathways_list)))
    m=m+1

KEGG_pathways_entrys.to_csv('KEGG\\KEGG_pathways_entrys.txt', header=True, index=False,sep='\t')

# %% [markdown]
# ## Read R entries

# %%
import pandas as pd
import re

KEGG_pathways_entrys = pd.read_csv('KEGG\\KEGG_pathways_entrys.txt', sep='\t',dtype={'pw_ID':str,'pw_name':str,'href':str,'title':str}).drop_duplicates()
KEGG_pathways_reactions = KEGG_pathways_entrys[KEGG_pathways_entrys['title'].str.contains(r'R\d{5}')]
ids =KEGG_pathways_entrys['title'].str.extract(r'(R\d{5})')
KEGG_pathways_reactions=KEGG_pathways_reactions.assign(R_ID = ids).drop_duplicates().reset_index()
KEGG_pathways_reactions.to_csv('KEGG\\KEGG_pathways_reactions.txt',sep='\t',index=False)

# %% [markdown]
# ## Download map picture

# %%
import pandas as pd
import requests
import json

with open('KEGG\\KEGG_pathways_name.json', 'r') as f:
    pathways_name_dir = json.load(f)
f.close()

pathways_list = [i for i in pathways_name_dir.keys()]

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'}

m = 1
for pathway in pathways_list:
    downloadurl = 'https://www.kegg.jp/kegg/pathway/map/'+pathway+'@2x.png'
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'}
    pict=requests.get(downloadurl,headers = headers).content
    with open('KEGG\\maps\\'+pathway+'.png','wb') as f:
        f.write(pict)
    print(pathway+' done!    '+str(m)+' / '+str(len(pathways_list)))
    m=m+1

# %% [markdown]
# # Download KEGG reaction/compound database

# %%
# download KEGG reactions
import requests
from lxml import etree
import re
import time
import pandas as pd

KEGG_REACTIONS_list = requests.get('https://rest.kegg.jp/list/reaction')
f = open("KEGG\\KEGG_REACTIONS_list.txt", 'w')
f.write(KEGG_REACTIONS_list.text)

kegg_rxn_list = pd.read_table('KEGG\\KEGG_REACTIONS_list.txt',header=None)
kegg_rlist = [st.replace('rn:','') for st in kegg_rxn_list[0]]

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'}
f = open("KEGG\\KEGG_REACTIONS_DB.txt", 'a')
f.write('ID\tNAMES\tKEGG\tEQUATION\tECs\n')

for id in kegg_rlist:
    url ='https://www.kegg.jp/entry/'+id
    try:
        html = requests.get(url,headers = headers)
    except requests.exceptions.Timeout:
        print("time out, try again")
        time.sleep(20)
        html = requests.get(url,headers = headers)
    if not html.ok:
        print('wrong reaction ID')
        time.sleep(20)
        html = requests.get(url,headers = headers)
        if not html.ok:
            continue

    e = etree.HTML(html.text)

    name_content = e.xpath('//th/span[text()="Name"]/../../td/div/div/text()')
    name = ''
    for st in name_content[:-1]:
        name = name +st.replace('\n','').replace(';','|')
    
    equation_content = e.xpath('//th/span[text()="Equation"]/../../td/div//text()')
    equation = ''
    for st in equation_content[:-1]:
        if st.startswith('C'):
            st = st+'[0]'
        else:
            matches = re.compile(r"\d+").findall(st)
            if matches:
                match = matches[0]
                st = st.replace(match, f"({match})")    
        equation = equation + st
    
    EC_content = e.xpath('//th/span[text()="Enzyme"]/../../td/div//text()')
    EC1 = [i.replace(u'\xa0','\n') for i in EC_content]
    EC2 = [i for i in EC1 if not str(i).startswith('\n')]
    EC = ''
    for st in EC2:
        EC = EC + st + '|'
    EC = EC[:-1]
    f.write(id+'\t'+name+'\t'+id+'\t'+equation+'\t'+EC+'\n')
f.close()

# %%
# KEGG reaction to ModelSEED reaction
import modelseedpy

modelseed_path = 'C:\\Users\\vickenlee\\ModelSEEDDatabase'
modelseed = modelseedpy.biochem.from_local(modelseed_path)

df_keggID_modelseedID = pd.DataFrame(columns=["Kegg_ID","ModelSeed_ID"])
for (key,value) in modelseed.reaction_aliases.items():
    ModelSeed_ID = key
    try:    
        Kegg_ID = list(value.get('KEGG'))[0]
    except:
            Kegg_ID =''
    df_keggID_modelseedID.loc[len(df_keggID_modelseedID.index)]=[Kegg_ID,ModelSeed_ID]
df_keggID_modelseedID.to_csv('KEGG\\KEGG_reaction_keggID_modelseedID.txt',  header=True, index=False,sep='\t')

print('done!')

# %%
# download KEGG compounds and map to ModelSEED compounds

KEGG_COMPOUNDS_list = requests.get('https://rest.kegg.jp/list/compound')
f = open("KEGG\\KEGG_COMPOUNDS_list.txt", 'w')
f.write(KEGG_COMPOUNDS_list.text)
kegg_cpd_list = pd.read_table('KEGG\\KEGG_COMPOUNDS_list.txt',header=None)
KEGG_COMPOUNDS_name = pd.DataFrame(columns=['ID','Name'])
KEGG_COMPOUNDS_name['ID']=[st.replace('cpd:','') for st in kegg_cpd_list[0]]
KEGG_COMPOUNDS_name['Name']=[st.replace('; ','|') for st in kegg_cpd_list[1]]


import modelseedpy
modelseed_path = 'C:\\Users\\vickenlee\\ModelSEEDDatabase'
modelseed = modelseedpy.biochem.from_local(modelseed_path)
cpd_keggID_modelseedID = pd.DataFrame(columns=["Kegg_ID","ModelSeed_ID","formula","charge"])
for (key,value) in modelseed.compound_aliases.items():
    ModelSeed_ID = key
    compound = modelseed.get_seed_compound(ModelSeed_ID)
    formula = compound.formula
    charge = compound.data['charge']
    try:    
        find_Kegg = list(value.get('KEGG'))
    except:
            find_Kegg =''
    if find_Kegg:
        for Kegg_ID in find_Kegg:
            cpd_keggID_modelseedID.loc[len(cpd_keggID_modelseedID.index)]=[Kegg_ID,ModelSeed_ID,formula,charge]
cpd_keggID_modelseedID.to_csv('KEGG\\KEGG_compound_keggID_modelseedID.txt', header=True,sep='\t',index=False)
cpd_keggID_modelseedID=cpd_keggID_modelseedID.rename(columns={'Kegg_ID':'ID'})


KEGG_COMPOUNDS_DB = pd.merge(KEGG_COMPOUNDS_name,cpd_keggID_modelseedID,how='left',on='ID').drop_duplicates(subset=['ID'], keep='first')


from lxml import etree
for index, row in KEGG_COMPOUNDS_DB.iterrows():
    if not row['formula']==row['formula']:
        url ='https://www.kegg.jp/entry/'+row['ID']
        try:
            html = requests.get(url,headers = headers)
        except requests.exceptions.Timeout:
            time.sleep(20)
            html = requests.get(url,headers = headers)
        e = etree.HTML(html.text)
        formula_content = e.xpath('//th/span[text()="Formula"]/../../td/div/text()')
        if formula_content:
            formula = formula_content[0]
            KEGG_COMPOUNDS_DB['formula'][index]=formula
            print(row['ID']+': add formula')
        else:
            print(row['ID']+': does not have formula')

KEGG_COMPOUNDS_DB.to_csv('Database\\KEGG_COMPOUNDS_DB.txt',sep='\t',index=None)

# %% [markdown]
# # Download species KEGG

# %%
org_name = 'mko'
org_full_name = 'Methylomonas_koyamae'

# %%
org_name = 'mbry'
org_full_name = 'Methylocystis_bryophila'

# %%
org_name = 'mca'
org_full_name = 'Methylococcus_capsulatus'

# %%
import myModules.KEGGdownload as kd

# %%
pwlist = kd.getpwlist(org_name)

# %%
kd.downloadxml(org_name,pwlist)

# %%
df_reaction = kd.getentriesfromxml(org_name)

# %% [markdown]
# # Get KEGG reaction from genome

# %%
org_name = 'mko'
org_full_name = 'Methylomonas_koyamae'

# %%
org_name = 'mbry'
org_full_name = 'Methylocystis_bryophila'

# %%
org_name = 'mca'
org_full_name = 'Methylococcus_capsulatus'

# %%
import os
faa_paths=[]
for root, dirs, files in os.walk('genome\\'+org_full_name+'_genome'):
    if 'protein.faa' in files:
        genome_path = root+'\\protein.faa'
print(genome_path)
# Out:
# genome\Methylocystis_bryophila_genome\ncbi_dataset\data\GCA_027925445.1\protein.faa

# %% [markdown]
# 1. upload protein.faa to https://www.kegg.jp/blastkoala/
#
# 2. download the blast result to genome\\XXX_genome\\user_ko.txt

# %%
from myModules.BIGG2KEGG import getRfromKO
import pandas as pd

df_org_ko = pd.read_csv('genome\\'+org_full_name+'_genome\\user_ko.txt',sep='\t',header=None)
df_org_ko.columns = ['Genes','KO_ID']
ko_list = df_org_ko['KO_ID'].tolist()
R_list =[]
for ko in ko_list:
    try:
        R = getRfromKO(ko)
        if type(R) == list:
            R_list+=R
        elif type(R) == str:
            R_list.append(R)
    except:
        continue
R_list = list(set(R_list))

with open('genome\\'+org_full_name+'_genome\\R_list.txt','w') as f:
    for R in R_list:
        f.write(str(R)+'\n')
f.close()
# Out:
# Cannot find R for K02884!
# Cannot find R for K17686!
# Cannot find R for K02911!
# Cannot find R for K02017!
# Cannot find R for K03553!
# Cannot find R for K03584!
# Cannot find R for K03575!
# Cannot find R for K02297!
# Cannot find R for K02298!
# Cannot find R for K02299!
# Cannot find R for K05592!
# Cannot find R for K02584!
# Cannot find R for K04761!
# Cannot find R for K13924!
# Cannot find R for K02887!
# Cannot find R for K02916!
# Cannot find R for K09689!
# Cannot find R for K10107!
# Cannot find R for K09688!
# Cannot find R for K10107!
# Cannot find R for K02040!
# Cannot find R for K03210!
# Cannot find R for K03074!
# Cannot find R for K11903!
# Cannot find R for K14987!
# Cannot find R for K03671!
# Cannot find R for K00333!
# Cannot find R for K14987!
# Cannot find R for K13924!
# Cannot find R for K14986!
# Cannot find R for K14987!
# Cannot find R for K01991!
# Cannot find R for K16554!
# Cannot find R for K01338!
# Cannot find R for K03544!
# Cannot find R for K03070!
# Cannot find R for K07716!
# Cannot find R for K02919!
# Cannot find R for K00990!
# Cannot find R for K02902!
# Cannot find R for K01999!
# Cannot find R for K14986!
# Cannot find R for K03628!
# Cannot find R for K02342!
# Cannot find R for K03629!
# Cannot find R for K02584!
# Cannot find R for K02986!
# Cannot find R for K07091!
# Cannot find R for K04079!
# Cannot find R for K00425!
# Cannot find R for K00426!
# Cannot find R for K02066!
# Cannot find R for K02065!
# Cannot find R for K02067!
# Cannot find R for K09691!
# Cannot find R for K09690!
# Cannot find R for K02909!
# Cannot find R for K02340!
# Cannot find R for K02113!
# Cannot find R for K02111!
# Cannot find R for K02115!
# Cannot find R for K02112!
# Cannot find R for K02114!
# Cannot find R for K01142!
# Cannot find R for K03695!
# Cannot find R for K06204!
# Cannot find R for K18139!
# Cannot find R for K07799!
# Cannot find R for K07788!
# Cannot find R for K07789!
# Cannot find R for K14475!
# Cannot find R for K04077!
# Cannot find R for K07675!
# Cannot find R for K07689!
# Cannot find R for K13993!
# Cannot find R for K03100!
# Cannot find R for K02413!
# Cannot find R for K07636!
# Cannot find R for K09808!
# Cannot find R for K09810!
# Cannot find R for K03587!
# Cannot find R for K03588!
# Cannot find R for K07213!
# Cannot find R for K13893!
# Cannot find R for K13894!
# Cannot find R for K13895!
# Cannot find R for K13896!
# Cannot find R for K03572!
# Cannot find R for K02339!
# Cannot find R for K02035!
# Cannot find R for K03071!
# Cannot find R for K03075!
# Cannot find R for K06861!
# Cannot find R for K10914!
# Cannot find R for K01246!
# Cannot find R for K19661!
# Cannot find R for K19641!
# Cannot find R for K03620!
# Cannot find R for K13582!
# Cannot find R for K03101!
# Cannot find R for K13587!
# Cannot find R for K03118!
# Cannot find R for K03117!
# Cannot find R for K03116!
# Cannot find R for K20265!
# Cannot find R for K20331!
# Cannot find R for K02939!
# Cannot find R for K13581!
# Cannot find R for K03470!
# Cannot find R for K01246!
# Cannot find R for K04043!
# Cannot find R for K00937!
# Cannot find R for K02990!
# Cannot find R for K02963!
# Cannot find R for K02112!
# Cannot find R for K02114!
# Cannot find R for K02108!
# Cannot find R for K02110!
# Cannot find R for K02109!
# Cannot find R for K02111!
# Cannot find R for K02115!
# Cannot find R for K03654!
# Cannot find R for K03703!
# Cannot find R for K10773!
# Cannot find R for K02358!
# Cannot find R for K04077!
# Cannot find R for K02338!
# Cannot find R for K04771!
# Cannot find R for K07323!
# Cannot find R for K01991!
# Cannot find R for K10912!
# Cannot find R for K02035!
# Cannot find R for K14987!
# Cannot find R for K02970!
# Cannot find R for K11357!
# Cannot find R for K03596!
# Cannot find R for K18164!
# Cannot find R for K21001!
# Cannot find R for K02456!
# Cannot find R for K13582!
# Cannot find R for K02459!
# Cannot find R for K02458!
# Cannot find R for K02457!
# Cannot find R for K02455!
# Cannot find R for K02454!
# Cannot find R for K02461!
# Cannot find R for K02462!
# Cannot find R for K02460!
# Cannot find R for K02453!
# Cannot find R for K05847!
# Cannot find R for K05845!
# Cannot find R for K05846!
# Cannot find R for K04564!
# Cannot find R for K01142!
# Cannot find R for K25307!
# Cannot find R for K01358!
# Cannot find R for K02950!
# Cannot find R for K02992!
# Cannot find R for K02358!
# Cannot find R for K02946!
# Cannot find R for K02906!
# Cannot find R for K02926!
# Cannot find R for K02892!
# Cannot find R for K02886!
# Cannot find R for K02965!
# Cannot find R for K02890!
# Cannot find R for K02982!
# Cannot find R for K02878!
# Cannot find R for K02904!
# Cannot find R for K02961!
# Cannot find R for K02874!
# Cannot find R for K02895!
# Cannot find R for K02931!
# Cannot find R for K02954!
# Cannot find R for K02994!
# Cannot find R for K02933!
# Cannot find R for K02881!
# Cannot find R for K02988!
# Cannot find R for K02907!
# Cannot find R for K02876!
# Cannot find R for K03076!
# Cannot find R for K02952!
# Cannot find R for K02948!
# Cannot find R for K03040!
# Cannot find R for K02879!
# Cannot find R for K02899!
# Cannot find R for K02888!
# Cannot find R for K02471!
# Cannot find R for K03648!
# Cannot find R for K09969!
# Cannot find R for K02575!
# Cannot find R for K03657!
# Cannot find R for K01644!
# Cannot find R for K01971!
# Cannot find R for K10979!
# Cannot find R for K13525!
# Cannot find R for K13993!
# Cannot find R for K07713!
# Cannot find R for K01141!
# Cannot find R for K03205!
# Cannot find R for K20527!
# Cannot find R for K20528!
# Cannot find R for K20529!
# Cannot find R for K20530!
# Cannot find R for K20266!
# Cannot find R for K20266!
# Cannot find R for K07344!
# Cannot find R for K20531!
# Cannot find R for K20532!
# Cannot find R for K20533!
# Cannot find R for K05367!
# Cannot find R for K02195!
# Cannot find R for K02196!
# Cannot find R for K00411!
# Cannot find R for K00410!
# Cannot find R for K00413!
# Cannot find R for K03655!
# Cannot find R for K02968!
# Cannot find R for K02313!
# Cannot find R for K11073!
# Cannot find R for K15012!
# Cannot find R for K03553!
# Cannot find R for K03602!
# Cannot find R for K08641!
# Cannot find R for K03723!
# Cannot find R for K01159!
# Cannot find R for K03550!
# Cannot find R for K19294!
# Cannot find R for K19295!
# Cannot find R for K01644!
# Cannot find R for K02897!
# Cannot find R for K03111!
# Cannot find R for K03701!
# Cannot find R for K24821!
# Cannot find R for K23163!
# Cannot find R for K02046!
# Cannot find R for K02047!
# Cannot find R for K02045!
# Cannot find R for K02471!
# Cannot find R for K05366!
# Cannot find R for K02275!
# Cannot find R for K02274!
# Cannot find R for K02258!
# Cannot find R for K02276!
# Cannot find R for K01507!
# Cannot find R for K07645!
# Cannot find R for K07666!
# Cannot find R for K07667!
# Cannot find R for K07646!
# Cannot find R for K01548!
# Cannot find R for K01547!
# Cannot find R for K01546!
# Cannot find R for K02335!
# Cannot find R for K01991!
# Cannot find R for K20326!
# Cannot find R for K03601!
# Cannot find R for K12340!
# Cannot find R for K10914!
# Cannot find R for K02806!
# Cannot find R for K03092!
# Cannot find R for K08300!
# Cannot find R for K05366!
# Cannot find R for K02314!
# Cannot find R for K07638!
# Cannot find R for K07659!
# Cannot find R for K09969!
# Cannot find R for K02337!
# Cannot find R for K18101!
# Cannot find R for K11443!
# Cannot find R for K02488!
# Cannot find R for K01354!
# Cannot find R for K02967!
# Cannot find R for K00970!
# Cannot find R for K11749!
# Cannot find R for K03110!
# Cannot find R for K02195!
# Cannot find R for K02196!
# Cannot find R for K03652!
# Cannot find R for K09969!
# Cannot find R for K03666!
# Cannot find R for K02109!
# Cannot find R for K02109!
# Cannot find R for K02110!
# Cannot find R for K02108!
# Cannot find R for K02341!
# Cannot find R for K07258!
# Cannot find R for K07462!
# Cannot find R for K02277!
# Cannot find R for K02276!
# Cannot find R for K02274!
# Cannot find R for K02275!
# Cannot find R for K13599!
# Cannot find R for K13598!
# Cannot find R for K07712!
# Cannot find R for K07708!
# Cannot find R for K03685!
# Cannot find R for K03100!
# Cannot find R for K02020!
# Cannot find R for K02018!
# Cannot find R for K02017!
# Cannot find R for K03060!
# Cannot find R for K11927!
# Cannot find R for K09812!
# Cannot find R for K09811!
# Cannot find R for K07789!
# Cannot find R for K07788!
# Cannot find R for K07799!
# Cannot find R for K00937!
# Cannot find R for K02020!
# Cannot find R for K10914!
# Cannot find R for K03531!
# Cannot find R for K03590!
# Cannot find R for K03589!
# Cannot find R for K06187!
# Cannot find R for K02343!
# Cannot find R for K02970!
# Cannot find R for K05966!
# Cannot find R for K01644!
# Cannot find R for K03555!
# Cannot find R for K16554!
# Cannot find R for K11076!
# Cannot find R for K11075!
# Cannot find R for K11074!
# Cannot find R for K07716!
# Cannot find R for K03073!
# Cannot find R for K02867!
# Cannot find R for K02863!
# Cannot find R for K09823!
# Cannot find R for K02945!
# Cannot find R for K04771!
# Cannot find R for K13589!
# Cannot find R for K10563!
# Cannot find R for K09969!
# Cannot find R for K08738!
# Cannot find R for K07685!
# Cannot find R for K13588!
# Cannot find R for K10914!
# Cannot find R for K03702!
# Cannot find R for K03217!
# Cannot find R for K02914!
# Cannot find R for K02871!
# Cannot find R for K02996!
# Cannot find R for K02913!
# Cannot find R for K08484!
# Cannot find R for K01972!
# Cannot find R for K03671!
# Cannot find R for K15011!
# Cannot find R for K12574!
# Cannot find R for K00343!
# Cannot find R for K00342!
# Cannot find R for K00341!
# Cannot find R for K00340!
# Cannot find R for K00339!
# Cannot find R for K00338!
# Cannot find R for K00337!
# Cannot find R for K00336!
# Cannot find R for K00335!
# Cannot find R for K00334!
# Cannot find R for K00333!
# Cannot find R for K00332!
# Cannot find R for K00331!
# Cannot find R for K00330!
# Cannot find R for K04751!
# Cannot find R for K02959!
# Cannot find R for K03106!
# Cannot find R for K21929!
# Cannot find R for K19294!
# Cannot find R for K11720!
# Cannot find R for K21029!
# Cannot find R for K04077!
# Cannot find R for K13924!
# Cannot find R for K01996!
# Cannot find R for K01999!
# Cannot find R for K01998!
# Cannot find R for K01997!
# Cannot find R for K01995!
# Cannot find R for K07689!
# Cannot find R for K07675!
# Cannot find R for K12340!
# Cannot find R for K14987!
# Cannot find R for K02277!
# Cannot find R for K02276!
# Cannot find R for K02276!
# Cannot find R for K02274!
# Cannot find R for K02275!
# Cannot find R for K05366!
# Cannot find R for K13584!
# Cannot find R for K03469!
# Cannot find R for K03154!
# Cannot find R for K04066!
# Cannot find R for K02784!
# Cannot find R for K14980!
# Cannot find R for K14981!
# Cannot find R for K13592!
# Cannot find R for K03636!
# Cannot find R for K01991!
# Cannot find R for K12573!
# Cannot find R for K20327!
# Cannot find R for K02864!
# Cannot find R for K02935!
# Cannot find R for K03043!
# Cannot find R for K03046!
# Cannot find R for K11103!
# Cannot find R for K03551!
# Cannot find R for K08311!
# Cannot find R for K00566!
# Cannot find R for K13583!
# Cannot find R for K07657!
# Cannot find R for K02036!
# Cannot find R for K02038!
# Cannot find R for K02037!
# Cannot find R for K02040!
# Cannot find R for K02956!
# Cannot find R for K00962!
# Cannot find R for K01535!
# Cannot find R for K09810!
# Cannot find R for K05685!
# Cannot find R for K02035!
# Cannot find R for K07789!
# Cannot find R for K07788!
# Cannot find R for K07799!
# Cannot find R for K18139!
# Cannot find R for K02584!
# Cannot find R for K02042!
# Cannot find R for K02044!
# Cannot find R for K02041!
# Cannot find R for K10914!
# Cannot find R for K02194!
# Cannot find R for K02193!
# Cannot find R for K02316!
# Cannot find R for K03086!
# Cannot find R for K13924!
# Cannot find R for K06160!
# Cannot find R for K03111!
# Cannot find R for K03111!
# Cannot find R for K03205!
# Cannot find R for K03196!
# Cannot find R for K03195!
# Cannot find R for K03204!
# Cannot find R for K03203!
# Cannot find R for K03201!
# Cannot find R for K03199!
# Cannot find R for K03198!
# Cannot find R for K03197!
# Cannot find R for K03657!

# %% [markdown]
# ### import from KEGG BLASTKOALA
