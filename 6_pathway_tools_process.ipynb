# %%
org_name = 'mbry'
org_full_name = 'Methylocystis_bryophila'

# %%
import cobra
DSM21852_model = cobra.io.read_sbml_model(org_name+'_model\\DSM21852pathwaytool_model.xml')
# Out:
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction RXN_17777 "RXN-17777">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction RXN_17777 "RXN-17777">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction RXN_11638 "RXN-11638">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction RXN_11638 "RXN-11638">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction TRNA_PSEUDOURIDINE_SYNTHASE_I_RXN "TRNA-PSEUDOURIDINE-SYNTHASE-I-RXN">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction TRNA_PSEUDOURIDINE_SYNTHASE_I_RXN "TRNA-PSEUDOURIDINE-SYNTHASE-I-RXN">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction _2__46__5__46__1__46__32_RXN "2.5.1.32-RXN">'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction _2__46__5__46__1__46__32_RXN "2.5.1.32-RXN">'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction RXNARA_8002 "RXNARA-8002">'
# ...

# %%
DSM21852_model.metabolites.get_by_id('CO+2')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 DSM21852_model.metabolites.get_by_id('CO+2')
#
# File c:\Users\vickenlee\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\dictlist.py:75, in DictList.get_by_id(self, id)
#      73 def get_by_id(self, id: Union[Object, str]) -> Object:
#      74     """Return the element with a matching id."""
# ---> 75     return list.__getitem__(self, self._dict[id])
#
# KeyError: 'CO+2'

# %%
for rxn in DSM21852_model.reactions:
    print(rxn.id,'\n', rxn.name,'\n', rxn.reaction,'\n','\n')
# Out:
# RXN_17777
#  RXN-17777
#  CPD_19171_c + NAD_c <=> CPD_19169_c + NADH_c + PROTON_c
#
#
# RXN_11638
#  RXN-11638
#  S_ADENOSYLMETHIONINE_c + _16S_rRNA_cytidine1402_c <=> ADENOSYL_HOMO_CYS_c + PROTON_c + _16S_rRNA_N4_methylcytidine1402_c
#
#
# TRNA_PSEUDOURIDINE_SYNTHASE_I_RXN
#  TRNA-PSEUDOURIDINE-SYNTHASE-I-RXN
#  tRNA_uridine_38_40_c <=> tRNA_pseudouridine_38_40_c
#
#
# _2.5.1.32_RXN
#  2.5.1.32-RXN
#  2.0 GERANYLGERANYL_PP_c <=> CPD_464_c + PPI_c
#
#
# RXNARA_8002
#  RXNARA-8002
#  CPD_464_c <=> CPD_12321_c + PPI_c
#
#
# RXN_13323
#  RXN-13323
#  2.0 GERANYLGERANYL_PP_c <=> CPD_12321_c + 2.0 PPI_c
#
#
# TRANS_RXN0_498
#  TRANS-RXN0-498
#  F__p <=> F__c
#
#
# RXN_18431
#  RXN-18431
#  CPD_19776_c <=> CPD_13734_c + WATER_c
#
#
# RXN_18430
#  RXN-18430
#  Acceptor_c + CPD_19775_c + WATER_c <=> CPD_19776_c + Donor_H2_c
#
#
# RXN_18428
#  RXN-18428
#  Acceptor_c + CPD_17063_c + WATER_c <=> CPD_19775_c + Donor_H2_c
#
#
# RXN_18399
#  RXN-18399
# ...

# %%
rxn
# Out:
# <Reaction UDP-NACMURALGLDAPLIG-RXN at 0x25a1f4601c0>
