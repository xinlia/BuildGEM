# %%
pip install requests
pip install lxml
pip install pandas
pip install openpyxl
pip install cobra
pip install cobrakbase
# for windows only, download the file from https://www.lfd.uci.edu/~gohlke/pythonlibs/#pyeda firstly
# pip install pyeda-0.28.0-cp37-cp37m-win_amd64.whl  
pip install modelseedpy

# %%
org_name = 'mko'
org_full_name = 'Methylomonas_koyamae'

# %%
org_name = 'mbry'
org_full_name = 'Methylocystis_bryophila'

# %% [markdown]
# # build model from modelseed

# %% [markdown]
# ## Auto build model from genome by modelseed

# %%
import modelseedpy
import sys
from modelseedpy import KBaseMediaPkg
from modelseedpy import FBAHelper, MSBuilder, MSGenome
from modelseedpy import RastClient
import os
import cobra
os.environ["HOME"] = "1"
import cobrakbase

# download genome from NCBI https://www.ncbi.nlm.nih.gov/data-hub/genome/GCA_027925445.1/
for root, dirs, files in os.walk(org_full_name+'_genome'):
    if 'protein.faa' in files:
        genome_path = root+'\\protein.faa'

genome = MSGenome.from_fasta(genome_path,split=' ')

# %%
rast = RastClient()
rast.annotate_genome(genome)

# %%
kbase_api = cobrakbase.KBaseAPI('5IS2FWVJ5FJZCHJ6KDTDHUUZLIXKTPQR')
kb_template = kbase_api.get_from_ws("GramNegModelTemplateV4","NewKBaseModelTemplates")
media1 = kbase_api.get_from_ws('Carbon-D-Glucose', 'KBaseMedia')
media2 = kbase_api.get_from_ws('C-acetate', 'KBaseMedia')

# %%
kb_template = kbase_api.get_from_ws("GramNegModelTemplateV4","NewKBaseModelTemplates")
driftmodel = MSBuilder.build_metabolic_model(org_full_name, genome, template = kb_template, allow_all_non_grp_reactions = True)
driftmodel
cobra.io.write_sbml_model(driftmodel,filename=org_name+'_model\\'+org_name+'_drift_model_from_modelseed.xml')

'''
or build this model by Kbase

'''

# %%
from cobrakbase.core.kbasefba.newmodeltemplate_builder import NewModelTemplateBuilder
from modelseedpy.helpers import get_template, get_classifier
template_core = get_template('template_core')
template_gramneg = get_template('template_gram_neg')
template_core = NewModelTemplateBuilder.from_dict(template_core, None).build()
template_gramneg = NewModelTemplateBuilder.from_dict(template_gramneg, None).build()
# Out:
# modelseedpy.helpers - WARNING - downloading data file to: c:\Users\vickenlee\AppData\Local\Programs\Python\Python39\lib\site-packages\modelseedpy//data/templates/template_core.json
# WARNING:modelseedpy.helpers:downloading data file to: c:\Users\vickenlee\AppData\Local\Programs\Python\Python39\lib\site-packages\modelseedpy//data/templates/template_core.json

# %%
model_builder = MSBuilder(genome, template_gramneg)
base_model = model_builder.build('model', '0', allow_all_non_grp_reactions=True, annotate_with_rast=False)
from modelseedpy.core.msbuilder import build_biomass, core_atp
base_model.add_reactions([build_biomass('bio2', base_model, template_core, core_atp, '0')])

# %% [markdown]
# ## Initialize new model

# %%
import cobra

new_model = cobra.Model(org_full_name)
new_model
# Out:
# <Model Methylomonas_koyamae at 0x275915d1f40>

# %% [markdown]
# ## KEGG ID mapping to modelseed

# %%
import pandas as pd

#org_name = 'mbry'
df_reaction = pd.read_excel(org_name+'_model\\'+org_name+'_clean_kegg_reaction.xlsx', index_col=1)  
titlename= ['entry_name','pathway_title','reaction_type','reaction_substrates','reaction_products']
df_keggID_modelseedID = pd.read_csv('reaction_keggID_modelseedID.txt', sep='\t')
mapping_reaction = pd.merge(df_reaction,df_keggID_modelseedID,how='left',on='Kegg_ID').drop_duplicates(subset=['Kegg_ID'], keep='first')[['ModelSeed_ID','Kegg_ID']+titlename]
mapping_reaction.to_excel(org_name+'_model\\'+org_name+'_mapping_reaction.xlsx', sheet_name='Sheet1', header=True)

print('done!')
# Out:
# done!

# %% [markdown]
# ## add reactions from drift model

# %%
import cobra
import pandas as pd
'''
org_name = 'mbry'
org_full_name = 'Methylocystis_bryophila'
drift_model_path = org_name+'_model\\ModelSeed_model_'+org_full_name+'.xml'
drift_model = cobra.io.read_sbml_model(drift_model_path)
new_model = cobra.io.read_sbml_model(org_name+'_model\\'+org_name+'_blank.xml')
'''

mapping_reaction = pd.read_excel(org_name+'_model\\'+org_name+'_mapping_reaction.xlsx', index_col=0)  
modelseed_id_list = list(mapping_reaction['ModelSeed_ID'].dropna(axis = 0, how = 'any'))  # reaction ID that need to be added

added_rxn_id_list = []
unadded_rxn_id_list = []
for rxn_id in modelseed_id_list:
    try:
        reaction = drift_model.reactions.get_by_id(rxn_id+'_c0')
        new_model.add_reactions([reaction])
    except:
        unadded_rxn_id_list.append(rxn_id)
        continue
    added_rxn_id_list.append(rxn_id)
'''
bioreaction = drift_model.reactions.get_by_id('bio1_biomass')
new_model.add_reactions([bioreaction])
new_model.objective = new_model.problem.Objective(bioreaction.flux_expression, direction='max')
'''
print(str(len(added_rxn_id_list)) + ' / ' + str(len(modelseed_id_list)) + ' reactions and biomass reaction are added, which are copied from drift model')


#cobra.io.write_sbml_model(new_model,filename=org_name+'_copyfrom_DriftModel.xml')

# %%
unadded_rxn_id_list
# Out:
# ['rxn40277',
#  'rxn40276',
#  'rxn40037',
#  'rxn40273',
#  'rxn40254',
#  'rxn40065',
#  'rxn39352',
#  'rxn40102',
#  'rxn40015',
#  'rxn40016',
#  'rxn40018',
#  'rxn40019',
#  'rxn40020',
#  'rxn40014',
#  'rxn39964',
#  'rxn40041',
#  'rxn40040']

# %% [markdown]
# ### add reactions not included in drift model

# %%
import cobra
import pandas as pd

import modelseedpy
modelseed_path = 'C:\\Users\\vickenlee\\ModelSEEDDatabase'
modelseed = modelseedpy.biochem.from_local(modelseed_path)


print('======================== \n %d reactions begin to added \n'%len(unadded_rxn_id_list))

i,j = 0,0
for rxn_id in unadded_rxn_id_list:
    reaction_type = mapping_reaction.query('ModelSeed_ID == "'+ rxn_id +'"')['reaction_type'].values[0]
    if reaction_type == 'reversible':
        direction = 'reversible'
    elif reaction_type == 'irreversible':
        direction = 'forward'
    try:
        add_ms_reaction(new_model, rxn_id = rxn_id, modelseed = modelseed, compartment = 'c0', direction = direction)
        print(rxn_id+' added')
        i+=1
    except:
        print(rxn_id+' added wrong !!!')
        j+=1

print('\n %d / %d reactions added successfully \n ====================='%(i,i+j))

for metabolite in new_model.metabolites:
    metaid = [meta for meta in metabolite.id.split('_') if meta.startswith('cpd')]
    if metaid:
        ms_metabolite = modelseed.get_seed_compound(metaid[0])
        if  ms_metabolite.formula == ms_metabolite.formula:
            metabolite.formula = ms_metabolite.formula
        metabolite.charge = ms_metabolite.data['charge']

# add gene
mapping_reaction = pd.read_excel(org_name+'_mapping_reaction.xlsx', index_col=0)  
i=1
for reaction in new_model.reactions:
    rxnid = [rxn for rxn in reaction.id.split('_') if rxn.startswith('rxn')]
    if rxnid:
        gene_list_str = '( '+mapping_reaction.query('ModelSeed_ID == "'+ rxnid[0] +'"')['entry_name'].values[0].replace(' ', ' or ')+' )'
        reaction.gene_reaction_rule = gene_list_str
    if i%100 == 0:
        print('%d / %d reactions added succesfully'%(i,len(new_model.reactions)))
    i+=1
print('%d / %d reactions added succesfully'%(len(new_model.reactions),len(new_model.reactions)))




cobra.io.write_sbml_model(new_model,filename=org_name+'_copyfrom_DriftModel_and_add_from_ModelSEED.xml')
# Out:
# ========================
#  433 reactions begin to added
#
# rxn15116 added
# rxn00536 added
# rxn15494 added
# rxn15364 added
# rxn15249 added
# rxn15694 added
# rxn15314 added
# rxn06120 added
# rxn15989 added
# rxn13974 added
# rxn00175 added
# rxn15298 added
# rxn00250 added
# rxn06109 added
# rxn15271 added
# rxn29919 added
# rxn00778 added
# rxn08647 added
# rxn03643 added
# rxn16622 added
# rxn00211 added
# rxn01042 added
# rxn15081 added
# rxn15270 added
# rxn02100 added
# rxn01008 added
# rxn07578 added
# rxn07576 added
# rxn07577 added
# rxn05336 added
# rxn05342 added
# rxn05340 added
# rxn05338 added
# rxn05341 added
# rxn05337 added
# rxn05339 added
# rxn00533 added
# rxn08766 added
# rxn05322 added
# rxn05326 added
# rxn05325 added
# rxn05327 added
# rxn05324 added
# rxn05323 added
# rxn05328 added
# rxn07455 added
# rxn00947 added
# rxn06237 added
# rxn05994 added
# rxn06238 added
# rxn05830 added
# rxn17757 added
# rxn05996 added
# rxn05871 added
# rxn14029 added
# rxn11642 added
# rxn11643 added
# rxn16584 added
# rxn07335 added
# rxn05004 added
# rxn16585 added
# rxn11156 added
# rxn11994 added
# rxn40277 added
# rxn40276 added
# rxn01917 added
# rxn01637 added
# rxn00560 added
# rxn05231 added
# rxn01649 added
# rxn01137 added
# rxn00916 added
# rxn01138 added
# rxn02449 added
# rxn01548 added
# rxn00514 added
# rxn01962 added
# rxn01139 added
# rxn01549 added
# rxn00307 added
# rxn03039 added
# rxn05114 added
# rxn05115 added
# rxn00140 added
# rxn02518 added
# rxn00063 added
# rxn00301 added
# rxn04783 added
# rxn00238 added
# rxn00134 added
# rxn01358 added
# rxn06075 added
# rxn00119 added
# rxn01360 added
# rxn06076 added
# rxn01517 added
# rxn14299 added
# rxn01367 added
# rxn00463 added
# rxn01704 added
# rxn00107 added
# rxn01219 added
# rxn00364 added
# rxn01648 added
# rxn01146 added
# rxn01366 added
# rxn00272 added
# rxn00503 added
# rxn00555 added
# rxn00509 added
# rxn00424 added
# rxn00422 added
# rxn00541 added
# rxn01833 added
# rxn04142 added
# rxn06044 added
# rxn00275 added
# rxn02928 added
# rxn40037 added
# rxn05957 added
# rxn05091 added
# rxn03057 added
# rxn01021 added
# rxn03052 added
# rxn00143 added
# rxn05107 added
# rxn00426 added
# rxn01757 added
# rxn01906 added
# rxn02229 added
# rxn15090 added
# rxn01303 added
# rxn04934 added
# rxn00738 added
# rxn16503 added
# rxn16511 added
# rxn05035 added
# rxn07435 added
# rxn07431 added
# rxn07433 added
# rxn07434 added
# rxn07430 added
# rxn07432 added
# rxn15510 added
# rxn05109 added
# rxn02751 added
# rxn00735 added
# rxn03435 added
# rxn15467 added
# rxn03436 added
# rxn15511 added
# rxn03068 added
# rxn08043 added
# rxn02749 added
# rxn15021 added
# rxn02011 added
# rxn11968 added
# rxn01418 added
# rxn01729 added
# rxn06112 added
# rxn02196 added
# rxn02826 added
# rxn02090 added
# rxn15949 added
# rxn15950 added
# rxn00853 added
# rxn00291 added
# rxn00467 added
# rxn05947 added
# rxn00183 added
# rxn02356 added
# rxn03071 added
# rxn03424 added
# rxn05776 added
# rxn15507 added
# rxn03426 added
# rxn00867 added
# rxn03195 added
# rxn03135 added
# rxn03345 added
# rxn01836 added
# rxn03333 added
# rxn03346 added
# rxn02087 added
# rxn02993 added
# rxn02397 added
# rxn03342 added
# rxn01715 added
# rxn01903 added
# rxn01004 added
# rxn01156 added
# rxn04598 added
# rxn04597 added
# rxn00489 added
# rxn04653 added
# rxn04650 added
# rxn02747 added
# rxn03801 added
# rxn03800 added
# rxn15998 added
# rxn07909 added
# rxn07908 added
# rxn03359 added
# rxn03358 added
# rxn02081 added
# rxn01564 added
# rxn02219 added
# rxn11962 added
# rxn00490 added
# rxn02476 added
# rxn16553 added
# rxn11571 added
# rxn06781 added
# rxn06421 added
# rxn03373 added
# rxn16206 added
# rxn16213 added
# rxn02525 added
# rxn01377 added
# rxn24067 added
# rxn25763 added
# rxn25680 added
# rxn01860 added
# rxn02139 added
# rxn06227 added
# rxn02008 added
# rxn06281 added
# rxn06168 added
# rxn12003 added
# rxn00198 added
# rxn00186 added
# rxn06401 added
# rxn12049 added
# rxn06272 added
# rxn06403 added
# rxn12204 added
# rxn06095 added
# rxn06096 added
# rxn15532 added
# rxn06165 added
# rxn40273 added
# rxn02284 added
# rxn00298 added
# rxn00016 added
# rxn15435 added
# rxn04703 added
# rxn16543 added
# rxn01750 added
# rxn06000 added
# rxn40254 added
# rxn40065 added
# rxn22648 added
# rxn13990 added
# rxn03919 added
# rxn03918 added
# rxn03916 added
# rxn03439 added
# rxn03182 added
# rxn16613 added
# rxn16611 added
# rxn03140 added
# rxn02286 added
# rxn04308 added
# rxn15315 added
# rxn39352 added
# rxn06140 added
# rxn00983 added
# rxn00765 added
# rxn06139 added
# rxn06671 added
# rxn06219 added
# rxn06362 added
# rxn01073 added
# rxn00616 added
# rxn06080 added
# rxn06043 added
# rxn06090 added
# rxn05970 added
# rxn06803 added
# rxn00758 added
# rxn06376 added
# rxn06091 added
# rxn06045 added
# rxn00176 added
# rxn00226 added
# rxn00227 added
# rxn16082 added
# rxn16084 added
# rxn06926 added
# rxn14054 added
# rxn14089 added
# rxn15990 added
# rxn04726 added
# rxn04736 added
# rxn00921 added
# rxn01034 added
# rxn03870 added
# rxn05851 added
# rxn00934 added
# rxn00682 added
# rxn00908 added
# rxn00675 added
# rxn00986 added
# rxn03061 added
# rxn02169 added
# rxn00868 added
# rxn01731 added
# rxn00684 added
# rxn01601 added
# rxn00907 added
# rxn06538 added
# rxn14120 added
# rxn16360 added
# rxn14207 added
# rxn07849 added
# rxn06294 added
# rxn10613 added
# rxn07848 added
# rxn07847 added
# rxn15964 added
# rxn03644 added
# rxn01539 added
# rxn40102 added
# rxn07292 added
# rxn02485 added
# rxn23042 added
# rxn00436 added
# rxn15951 added
# rxn02988 added
# rxn02154 added
# rxn01669 added
# rxn01265 added
# rxn00076 added
# rxn00105 added
# rxn02176 added
# rxn02128 added
# rxn15466 added
# rxn06023 added
# rxn06864 added
# rxn00792 added
# rxn14045 added
# rxn02277 added
# rxn16573 added
# rxn21864 added
# rxn16385 added
# rxn40015 added
# rxn40016 added
# rxn40018 added
# rxn40019 added
# rxn40020 added
# rxn40014 added
# rxn15454 added
# rxn02986 added
# rxn16231 added
# rxn16232 added
# rxn16806 added
# rxn39964 added
# rxn16824 added
# rxn07436 added
# rxn10543 added
# rxn16574 added
# rxn16583 added
# rxn01323 added
# rxn05120 added
# rxn00056 added
# rxn02287 added
# rxn02056 added
# rxn02774 added
# rxn06887 added
# rxn03542 added
# rxn06979 added
# rxn03540 added
# rxn01084 added
# rxn03538 added
# rxn03150 added
# rxn05121 added
# rxn05054 added
# rxn04384 added
# rxn14070 added
# rxn08352 added
# rxn04113 added
# rxn09037 added
# rxn16686 added
# rxn07469 added
# rxn07468 added
# rxn16635 added
# rxn16594 added
# rxn16514 added
# rxn00498 added
# rxn05070 added
# rxn05071 added
# rxn14358 added
# rxn00109 added
# rxn00567 added
# rxn05801 added
# rxn14010 added
# rxn00388 added
# rxn00102 added
# rxn01350 added
# rxn40041 added
# rxn16341 added
# rxn40040 added
# rxn14050 added
# rxn06440 added
# rxn06439 added
# rxn06444 added
# rxn06432 added
# rxn06437 added
# rxn06435 added
# rxn06438 added
# rxn06936 added
# rxn06446 added
# rxn06443 added
# rxn06449 added
# rxn06300 added
# rxn06442 added
# rxn06441 added
# rxn06447 added
# rxn06448 added
# rxn06280 added
# rxn10534 added
# rxn11595 added
# rxn11747 added
# rxn03402 added
# rxn00504 added
# rxn09188 added
# rxn02358 added
# rxn03072 added
# rxn05982 added
# rxn02285 added
# rxn01667 added
# rxn12649 added
# rxn05890 added
#
#  433 / 433 reactions added successfully
#  =====================
# 100 / 805 reactions added succesfully
# 200 / 805 reactions added succesfully
# 300 / 805 reactions added succesfully
# 400 / 805 reactions added succesfully
# 500 / 805 reactions added succesfully
# 600 / 805 reactions added succesfully
# 700 / 805 reactions added succesfully
# 800 / 805 reactions added succesfully
# 805 / 805 reactions added succesfully
