# %%
pip install requests
pip install lxml
pip install pandas
pip install openpyxl
pip install cobra

# for windows only, download the file from https://www.lfd.uci.edu/~gohlke/pythonlibs/#pyeda firstly
# pip install pyeda-0.28.0-cp37-cp37m-win_amd64.whl  
pip install modelseedpy

# %% [markdown]
# # get reaction included in KEGG pythway

# %% [markdown]
# ## get pythway ID list from kegg

# %%
import requests
from lxml import etree
org_name = 'mbry'
url ='https://www.kegg.jp/kegg-bin/show_organism?menu_type=pathway_maps&org='+org_name
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'}
html = requests.get(url,headers = headers)
if not html.ok:
    raise TypeError('wrong KEGG name')
e = etree.HTML(html.text)
strain_name = e.xpath('//font[@class="title1"]/text()')
print('Organism: '+strain_name[0]+'\n')
DATA = e.xpath('//ul/a/@href')
pathway_ID = [i.replace('/pathway/','') for i in DATA]
print(str(len(pathway_ID))+' pathway maps are found')
# Out:
# Organism: Methylocystis bryophila
#
# 118 pathway maps are found

# %% [markdown]
# ## download xml files

# %%
import re
import os
import requests

# create folder
path=".\\"+org_name
if not os.path.exists(path):
    os.makedirs(path)
    os.makedirs(path+'_model')
#download xml   
i = 1
for ID in pathway_ID:
    downloadurl = 'https://www.kegg.jp/kegg-bin/download?entry='+ID+'&format=kgml'
    headers={'Referer':'https://www.kegg.jp/pathway/'+ID,'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'}
    xml=requests.get(downloadurl,headers = headers)
    if not xml.ok:
        print(ID+'.xml can not be found.   '+str(i)+'/'+ str(len(pathway_ID)))
        i+=1
        continue
    with open(path+'\\'+ID+".xml","wb") as code:
        code.write(xml.content)
    print(ID+'.xml write secceed.   '+str(i)+'/'+ str(len(pathway_ID)))
    i+=1

# %% [markdown]
# ## get xml detail

# %%
from Bio.KEGG.KGML.KGML_parser import read
pathway = read(open('mbry/mbry00010.xml', 'r'))

# %%
pathway.name
# Out:
# 'path:mbry00010'

# %%
for entry in pathway.reaction_entries:
    print(entry)
# Out:
# Entry node ID: 42
# Names: mbry:B1812_01610
# Type: gene
# Components: set()
# Reactions: rn:R00710
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE658BDC0>]
#
# Entry node ID: 49
# Names: mbry:B1812_03385
# Type: gene
# Components: set()
# Reactions: rn:R00746
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4BA6880>]
#
# Entry node ID: 50
# Names: mbry:B1812_18345
# Type: gene
# Components: set()
# Reactions: rn:R00754
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4BA68E0>]
#
# Entry node ID: 52
# Names: mbry:B1812_18230 mbry:B1812_18235
# Type: gene
# Components: set()
# Reactions: rn:R00014
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4BA69A0>]
#
# Entry node ID: 53
# Names: mbry:B1812_18230 mbry:B1812_18235
# Type: gene
# Components: set()
# Reactions: rn:R03270
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4BA6A00>]
#
# Entry node ID: 54
# Names: mbry:B1812_10465
# Type: gene
# Components: set()
# Reactions: rn:R02569
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4BA6A60>]
#
# Entry node ID: 57
# Names: mbry:B1812_06770 mbry:B1812_06945
# Type: gene
# Components: set()
# Reactions: rn:R00200
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4BA6B80>]
#
# Entry node ID: 59
# Names: mbry:B1812_10045
# Type: gene
# Components: set()
# Reactions: rn:R00658
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4BA6C40>]
#
# Entry node ID: 60
# Names: mbry:B1812_08650 mbry:B1812_20140
# Type: gene
# Components: set()
# Reactions: rn:R01518
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4BA6CA0>]
#
# Entry node ID: 61
# Names: mbry:B1812_12285
# Type: gene
# Components: set()
# Reactions: rn:R01061
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4BA6D00>]
#
# Entry node ID: 62
# Names: mbry:B1812_03480
# Type: gene
# Components: set()
# Reactions: rn:R01015
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4BA6D60>]
#
# Entry node ID: 18
# Names: mbry:B1812_09170 mbry:B1812_11395
# Type: gene
# Components: set()
# Reactions: rn:R01070
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE658BAC0>]
#
# Entry node ID: 63
# Names: mbry:B1812_09340
# Type: gene
# Components: set()
# Reactions: rn:R04779
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4BA6DC0>]
#
# Entry node ID: 66
# Names: mbry:B1812_03175 mbry:B1812_07720
# Type: gene
# Components: set()
# Reactions: rn:R02740
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4BA6EE0>]
#
# Entry node ID: 67
# Names: mbry:B1812_02305
# Type: gene
# Components: set()
# Reactions: rn:R00959
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4BA6F40>]
#
# Entry node ID: 68
# Names: mbry:B1812_03175 mbry:B1812_07720
# Type: gene
# Components: set()
# Reactions: rn:R03321
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4BA6FA0>]
#
# Entry node ID: 70
# Names: mbry:B1812_15765
# Type: gene
# Components: set()
# Reactions: rn:R01600
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4C0E0A0>]
#
# Entry node ID: 71
# Names: mbry:B1812_03175 mbry:B1812_07720
# Type: gene
# Components: set()
# Reactions: rn:R02739
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4C0E100>]
#
# Entry node ID: 74
# Names: mbry:B1812_15765
# Type: gene
# Components: set()
# Reactions: rn:R01786
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4C0E220>]
#
# Entry node ID: 79
# Names: mbry:B1812_15670 mbry:B1812_17770
# Type: gene
# Components: set()
# Reactions: rn:R07618
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4C0E400>]
#
# Entry node ID: 80
# Names: mbry:B1812_12300
# Type: gene
# Components: set()
# Reactions: rn:R01512
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4C0E460>]
#
# Entry node ID: 120
# Names: mbry:B1812_04775
# Type: gene
# Components: set()
# Reactions: rn:R09127
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4C191C0>]
#
# Entry node ID: 121
# Names: mbry:B1812_19060
# Type: gene
# Components: set()
# Reactions: rn:R00341
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4C19220>]
#
# Entry node ID: 140
# Names: mbry:B1812_11570
# Type: gene
# Components: set()
# Reactions: rn:R00235
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4C19640>]
#
# Entry node ID: 148
# Names: mbry:B1812_07075 mbry:B1812_13450
# Type: gene
# Components: set()
# Reactions: rn:R00711
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4C198E0>]
#
# Entry node ID: 156
# Names: mbry:B1812_09340
# Type: gene
# Components: set()
# Reactions: rn:R02073
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4C19AC0>]
#
# Entry node ID: 159
# Names: mbry:B1812_18215
# Type: gene
# Components: set()
# Reactions: rn:R00199
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4C19BE0>]
#
# Entry node ID: 158
# Names: mbry:B1812_03055
# Type: gene
# Components: set()
# Reactions: rn:R00206
# Graphics elements: 1 [<Bio.KEGG.KGML.KGML_pathway.Graphics object at 0x000001CCE4C19B80>]

# %%
for reaction in pathway.reaction_entries:
    print(reaction.reaction, reaction.name)
# Out:
# rn:R00710 mbry:B1812_01610
# rn:R00746 mbry:B1812_03385
# rn:R00754 mbry:B1812_18345
# rn:R00014 mbry:B1812_18230 mbry:B1812_18235
# rn:R03270 mbry:B1812_18230 mbry:B1812_18235
# rn:R02569 mbry:B1812_10465
# rn:R00200 mbry:B1812_06770 mbry:B1812_06945
# rn:R00658 mbry:B1812_10045
# rn:R01518 mbry:B1812_08650 mbry:B1812_20140
# rn:R01061 mbry:B1812_12285
# rn:R01015 mbry:B1812_03480
# rn:R01070 mbry:B1812_09170 mbry:B1812_11395
# rn:R04779 mbry:B1812_09340
# rn:R02740 mbry:B1812_03175 mbry:B1812_07720
# rn:R00959 mbry:B1812_02305
# rn:R03321 mbry:B1812_03175 mbry:B1812_07720
# rn:R01600 mbry:B1812_15765
# rn:R02739 mbry:B1812_03175 mbry:B1812_07720
# rn:R01786 mbry:B1812_15765
# rn:R07618 mbry:B1812_15670 mbry:B1812_17770
# rn:R01512 mbry:B1812_12300
# rn:R09127 mbry:B1812_04775
# rn:R00341 mbry:B1812_19060
# rn:R00235 mbry:B1812_11570
# rn:R00711 mbry:B1812_07075 mbry:B1812_13450
# rn:R02073 mbry:B1812_09340
# rn:R00199 mbry:B1812_18215
# rn:R00206 mbry:B1812_03055

# %%
org_name
# Out:
# 'mca'

# %%
import os
import xml.dom.minidom as xo
import pandas as pd

path=".\\"+org_name
xmls = [path+'\\'+i for i in os.listdir(path) if i.endswith('.xml')]
df_xmlentry = pd.DataFrame(columns=["pathway_ID", "pathway_title", "entry_id", "entry_name","entry_type","entry_reaction","entry_link"])
df_xmlreaction = pd.DataFrame(columns=["reaction_ID", "reaction_name", "reaction_type", "reaction_substrates","reaction_products"])
i=1
for xml in xmls:
    domtree = xo.parse(xml)
    pathway = domtree.documentElement
    pathway_ID = pathway.getAttribute("name")
    pathway_org = pathway.getAttribute("org")
    pathway_title = pathway.getAttribute("title")
    entrys = pathway.getElementsByTagName("entry")
    reactions = pathway.getElementsByTagName("reaction")
    for entry in entrys:
        entry_id= pathway_ID+'-'+entry.getAttribute("id")
        entry_name = entry.getAttribute("name")
        entry_type = entry.getAttribute("type")
        entry_reaction = entry.getAttribute("reaction")
        entry_link = entry.getAttribute("link")
        data = [pathway_ID,pathway_title,entry_id,entry_name,entry_type,entry_reaction,entry_link]
        df_xmlentry.loc[len(df_xmlentry.index)]=data
        #graphics = entry.getElementsByTagName('graphics')[0]
        #graphics_name = graphics.getAttribute("name")
    for reaction in reactions:
        reaction_id = pathway_ID+'-'+reaction.getAttribute("id")
        reaction_name = reaction.getAttribute("name")
        reaction_type = reaction.getAttribute("type")
        substrates = reaction.getElementsByTagName("substrate")
        reaction_substrates = [substrate.getAttribute("name") for substrate in substrates]
        products = reaction.getElementsByTagName("product")
        reaction_products = [product.getAttribute("name") for product in products]
        data = [reaction_id, reaction_name, reaction_type, str(reaction_substrates),str(reaction_products)]
        df_xmlreaction.loc[len(df_xmlreaction.index)]=data
    print('File:',xml,'done.  ',i,'/',len(xmls))
    i+=1

df_r = df_xmlreaction.rename(columns={'reaction_name':'entry_reaction'}).drop(columns='reaction_ID')
df_org_reaction = pd.merge(df_xmlentry.query('entry_type == "gene" and entry_reaction != ""'),df_r,how='left', on='entry_reaction').drop_duplicates(subset=['entry_reaction'])

df_org_reaction.to_excel(org_name+'_model\\'+org_name+'_KEGG_pathway_reaction.xlsx', sheet_name='Sheet1', header=True)
# Out:
# File: .\mca\mca00010.xml done.   1 / 104
# File: .\mca\mca00020.xml done.   2 / 104
# File: .\mca\mca00030.xml done.   3 / 104
# File: .\mca\mca00040.xml done.   4 / 104
# File: .\mca\mca00051.xml done.   5 / 104
# File: .\mca\mca00052.xml done.   6 / 104
# File: .\mca\mca00053.xml done.   7 / 104
# File: .\mca\mca00061.xml done.   8 / 104
# File: .\mca\mca00071.xml done.   9 / 104
# File: .\mca\mca00100.xml done.   10 / 104
# File: .\mca\mca00130.xml done.   11 / 104
# File: .\mca\mca00190.xml done.   12 / 104
# File: .\mca\mca00220.xml done.   13 / 104
# File: .\mca\mca00230.xml done.   14 / 104
# File: .\mca\mca00240.xml done.   15 / 104
# File: .\mca\mca00250.xml done.   16 / 104
# File: .\mca\mca00260.xml done.   17 / 104
# File: .\mca\mca00261.xml done.   18 / 104
# File: .\mca\mca00270.xml done.   19 / 104
# File: .\mca\mca00280.xml done.   20 / 104
# File: .\mca\mca00290.xml done.   21 / 104
# File: .\mca\mca00300.xml done.   22 / 104
# File: .\mca\mca00310.xml done.   23 / 104
# File: .\mca\mca00330.xml done.   24 / 104
# File: .\mca\mca00332.xml done.   25 / 104
# File: .\mca\mca00340.xml done.   26 / 104
# File: .\mca\mca00350.xml done.   27 / 104
# File: .\mca\mca00360.xml done.   28 / 104
# File: .\mca\mca00362.xml done.   29 / 104
# File: .\mca\mca00380.xml done.   30 / 104
# File: .\mca\mca00400.xml done.   31 / 104
# File: .\mca\mca00401.xml done.   32 / 104
# File: .\mca\mca00410.xml done.   33 / 104
# File: .\mca\mca00430.xml done.   34 / 104
# File: .\mca\mca00450.xml done.   35 / 104
# File: .\mca\mca00460.xml done.   36 / 104
# File: .\mca\mca00470.xml done.   37 / 104
# File: .\mca\mca00480.xml done.   38 / 104
# File: .\mca\mca00500.xml done.   39 / 104
# File: .\mca\mca00514.xml done.   40 / 104
# File: .\mca\mca00515.xml done.   41 / 104
# File: .\mca\mca00520.xml done.   42 / 104
# File: .\mca\mca00521.xml done.   43 / 104
# File: .\mca\mca00523.xml done.   44 / 104
# File: .\mca\mca00525.xml done.   45 / 104
# File: .\mca\mca00540.xml done.   46 / 104
# File: .\mca\mca00541.xml done.   47 / 104
# File: .\mca\mca00542.xml done.   48 / 104
# File: .\mca\mca00543.xml done.   49 / 104
# File: .\mca\mca00550.xml done.   50 / 104
# File: .\mca\mca00552.xml done.   51 / 104
# File: .\mca\mca00561.xml done.   52 / 104
# File: .\mca\mca00562.xml done.   53 / 104
# File: .\mca\mca00564.xml done.   54 / 104
# File: .\mca\mca00620.xml done.   55 / 104
# File: .\mca\mca00623.xml done.   56 / 104
# File: .\mca\mca00625.xml done.   57 / 104
# File: .\mca\mca00626.xml done.   58 / 104
# File: .\mca\mca00627.xml done.   59 / 104
# File: .\mca\mca00630.xml done.   60 / 104
# File: .\mca\mca00633.xml done.   61 / 104
# File: .\mca\mca00640.xml done.   62 / 104
# File: .\mca\mca00643.xml done.   63 / 104
# File: .\mca\mca00650.xml done.   64 / 104
# File: .\mca\mca00660.xml done.   65 / 104
# File: .\mca\mca00670.xml done.   66 / 104
# File: .\mca\mca00680.xml done.   67 / 104
# File: .\mca\mca00730.xml done.   68 / 104
# File: .\mca\mca00740.xml done.   69 / 104
# File: .\mca\mca00750.xml done.   70 / 104
# File: .\mca\mca00760.xml done.   71 / 104
# File: .\mca\mca00770.xml done.   72 / 104
# File: .\mca\mca00780.xml done.   73 / 104
# File: .\mca\mca00785.xml done.   74 / 104
# File: .\mca\mca00790.xml done.   75 / 104
# File: .\mca\mca00860.xml done.   76 / 104
# File: .\mca\mca00900.xml done.   77 / 104
# File: .\mca\mca00906.xml done.   78 / 104
# File: .\mca\mca00909.xml done.   79 / 104
# File: .\mca\mca00910.xml done.   80 / 104
# File: .\mca\mca00920.xml done.   81 / 104
# File: .\mca\mca00946.xml done.   82 / 104
# File: .\mca\mca00970.xml done.   83 / 104
# File: .\mca\mca00999.xml done.   84 / 104
# File: .\mca\mca01040.xml done.   85 / 104
# File: .\mca\mca01501.xml done.   86 / 104
# File: .\mca\mca01502.xml done.   87 / 104
# File: .\mca\mca01503.xml done.   88 / 104
# File: .\mca\mca02010.xml done.   89 / 104
# File: .\mca\mca02020.xml done.   90 / 104
# File: .\mca\mca02024.xml done.   91 / 104
# File: .\mca\mca02030.xml done.   92 / 104
# File: .\mca\mca02040.xml done.   93 / 104
# File: .\mca\mca03010.xml done.   94 / 104
# File: .\mca\mca03018.xml done.   95 / 104
# File: .\mca\mca03020.xml done.   96 / 104
# File: .\mca\mca03030.xml done.   97 / 104
# File: .\mca\mca03060.xml done.   98 / 104
# File: .\mca\mca03070.xml done.   99 / 104
# File: .\mca\mca03410.xml done.   100 / 104
# File: .\mca\mca03420.xml done.   101 / 104
# File: .\mca\mca03430.xml done.   102 / 104
# File: .\mca\mca03440.xml done.   103 / 104
# File: .\mca\mca04122.xml done.   104 / 104

# %% [markdown]
# ## data clean

# %%
import pandas as pd

df_org_reaction = pd.read_excel(org_name+'_model\\'+org_name+'_KEGG_pathway_reaction.xlsx')  
titlename= ['entry_name','pathway_title','reaction_type','reaction_substrates','reaction_products']
df_gene = df_org_reaction[['entry_reaction']+titlename]
df_reaction_list = pd.concat([df_gene['entry_reaction'].str.split('rn:',expand=True).iloc[:,1:],df_gene[titlename]],axis=1)
df_reaction_melt = df_reaction_list.melt(id_vars = titlename, value_vars = [1,2,3,4],var_name = 'r',value_name = 'Kegg_ID').drop(['r'],axis = 1).dropna(subset=['Kegg_ID'])
df_reaction_melt['Kegg_ID'] = df_reaction_melt['Kegg_ID'].str.strip()
df_reaction = df_reaction_melt.drop_duplicates(subset=['Kegg_ID'])[['Kegg_ID']+titlename]
df_reaction.to_excel(org_name+'_model\\'+org_name+'_clean_kegg_reaction.xlsx', sheet_name='Sheet1', header=True)
